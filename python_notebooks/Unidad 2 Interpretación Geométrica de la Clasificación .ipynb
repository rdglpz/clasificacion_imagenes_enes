# %% [markdown]
# # Unidad 2 Interpretación Geométrica de la Clasificación

# %% [markdown]
# * En realidad se trata de un método de clasificación
# * Es la generalización de la regresión lineal $y = \mathbf{x}^T\mathbf{y} + b$
# * La variable de respuesta es binaria $y\in{0,1}$
#
#
# La regresión logística esta dada por :
#
# $$p(y|\mathbf{x,w}) = Ber(y|sigm(\mathbf{w^T x}))$$ donde:
#
# $sigm(\mathbf{w^T x}) = \frac{1}{1+e^{(-\mathbf{w}^T \mathbf{x})}} $

# %% [markdown]
# **Formulando la función Objetivo**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(-10,10)
y = np.ones(len(x))
y[:4] = 0 
theta = 3

# %% [markdown]
# $sigm(x,\theta) = \frac{1}{1+e^{(-\theta*x)}}$

# %%
def sigm(x,theta):
    return 1/(1+np.exp(-(20+theta*x)))

              
f2 = lambda x:sigm(x,theta)    

plt.plot(list(map(f2,x)))

# %%
list(map(f,x))
# Out:
# [9.357622968839299e-14,
#  1.8795288165355508e-12,
#  3.7751345441365816e-11,
#  7.582560422162385e-10,
#  1.522997951276035e-08,
#  3.059022269256247e-07,
#  6.144174602214718e-06,
#  0.00012339457598623172,
#  0.0024726231566347743,
#  0.04742587317756678,
#  0.5,
#  0.9525741268224334,
#  0.9975273768433653,
#  0.9998766054240137,
#  0.9999938558253978,
#  0.999999694097773,
#  0.9999999847700205,
#  0.9999999992417439,
#  0.9999999999622486,
#  0.9999999999981204]

# %%
def sigm(x,theta):
    return 1/(1+np.exp(-(theta*x)))

              
f = lambda x:sigm(x,theta)

# %%
#plt.plot(list(map(f,x)))
plt.plot(list(map(f2,x)))

# %%
f = lambda x:sigm(x,theta)


fig, ax = plt.subplots()
ax.plot(x,y,'x') 
ax.plot(x,y_hat,'r+') 
ax.plot(x,sigmoid,'b') 
ax.axhline(0.5)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,y,'x') 
ax.plot(x,y_hat,'r+') 
ax.plot(x,sigmoid,'b') 
ax.axhline(0.5)
plt.show()

# %% [markdown]
# https://matplotlib.org/stable/api/markers_api.html
