# %% [markdown]
# # Entrenamiento de una Red neuronal Pequeña.
# Código Basado en https://machinelearningmastery.com/implement-backpropagation-algorithm-scratch-python/

# %%
from math import exp
from random import seed, random
import math

# %% [markdown]
# * Una red neuronal es una función universal con  3 tipos de capas:
#
# 1) 1 capa de entrada,
# 2) capas intermedias,
# 3) 1 capa de salida.
#
# * Un problema es que la derivada calculada directamte es muy costosa computancionalmente.
#
# * Por lo tanto se requiere un algoritmo que considere este aspecto. Para esto se utiliza la regla de la cadena en cálculo. Esta poderosa herramienta resuelve funciones funciones anidadas: $y=g(x), z = f(y)$ o bien $z = f(g(x))$ de una manera muy eficiente.
#
# $$\frac{d z}{d x} = \frac{dz}{dy} \frac{dy}{dz} $$
#
# * El algoritmo de **Propagación hacia atrás** (Backpropagation, BP), es un algoritmo que forma parte del entrenamiento supervisado.
# Permite calcular las derivadas parcialeso gradientes asociadas a cada neurona de una red neuronal y con esta información actualizar los pesos de todas las capas intermedias.
#
# * Por lo tanto describiremos un código de una red neuronal con fines didácticos.

# %% [markdown]
# Ejemplo Red neuronal multicapa

# %% [markdown]
# Algoritmo general de entrenamiento de una red neuronal.
#
# * red = nueva_red()
# * hacer para $t$ iteraciones
#     * Por cada dato $i$,  $\{\mathbf{x}_i,y_i\}_{i=1}^n$
#         *  $\hat{z_i} = $propagar(red,$\{\mathbf{x}_i,y_i\}$)
#         *  retropropagar(red,$\hat{z_i}$ )  # aquí se calculan los incrementos o deltas a partir de las derivadas parciales
#         * actualizar_pesos(red,$\{x_i,y_i\}$)

# %% [markdown]
# Algoritmo de Backpropagation
#
# * Invertir el orden de las capas de la red.
# * Comenzar con la capa de salida
#
# * Para la última capa
#     * err = lista()
#     * por cada neurona i en la última capa de la red:
#         * $\hat{z} = capa.neurona[i].salida$
#         * $e=L(\hat{z},z)$ #medir el error.
#         * $err = err + e$ # agregar $e$ a la lista de errores de cada neurona $err$
#
#     #aqui guardamos los delta asociada a cada neurona de la  cada capa
#     * para cada neurona i en la última capa de la red j:
#         * $neurona[i].delta = err[i]*derivada(neurona[i].salida)$
#
#
#
#
# * hacer para cada capa $c$ de la red neuronal
#     * err = lista() # inicializar lista de errores errores
#     * para cada neurona $j$ de la capa $c$:
#         * error = 0.0
#         * para cada $neurona$ $j$ in la capa siguiente $c + 1$:
#             * error += (neurona[j].pesos * neurona.delta
#         * $err = err + e$ # agregar $e$ a la lista de errores de cada neurona $err$

# %%
# Propaga el error hacia atrás y lo va guardando en la estructura de la red
def backward_propagate_error(network, expected):
    
    #comenzamos con la capa de salida
    for i in reversed(range(len(network))):
        
        # por cada capa de la red asignada a layer
        layer = network[i]
        
        #el tamaño de la capa es equivalente al numero de neuronas en la capa
        n_neuronas = len(layer)
        
        #inicializamos error
        errors = list()
        
        # la primera vez calculamos sobre la ultima capa que es a la que tenemos acceso en un inicio
        if i == len(network)-1:
            
            # aquí se utiliza el error.
            
            # por cada neurona de la capa hacer:
            for j in range(n_neuronas):
                
                
                #asignamos la neurona j de la capa i
                neuron = layer[j]
                
                #asignamos la salida de la red neuronal previamente calculada
                yhat = neuron['output']
                
                #y será la salida real del conjunto de datos
                y = expected[0]
            
                #esta es la derivada de la función de costo basada en la log-verosimilitud
                # LL(\theta) = (y log yhat + (1-y) log [1-yhat])
                
                # Aqui comienza la transferencia, con la derivada de LL(\theta)
                e = (yhat-y)/((yhat-1)*yhat)
                errors.append(e)
        
        else:
            #aquí son las capas restantes hacia atrás donde propagamos el error
            
            for j in range(n_neuronas):
                error = 0.0
                for neuron in network[i + 1]:
                    
                    error += (neuron['weights'][j] * neuron['delta'])
                errors.append(error)
                
        #aqui guardamos todos los delta asociada a cada neurona de cada capa
        for j in range(n_neuronas):
            neuron = layer[j]
            
            #el error magnifica el delta que depende de derivada de transferencia
            neuron['delta'] = errors[j] * transfer_derivative(neuron['output'])

# %%
network[1]
# Out:
# [{'weights': [-1.306117824465025,
#    -2.0670118970079696,
#    -1.6257166643661571,
#    8.341962100677772,
#    -1.8423425412675547],
#   'output': 0.8163166539452361,
#   'delta': 0.18368334605476389}]

# %%
i=0
layer = network[i]
n_neuronas = len(layer)
for j in range(n_neuronas):
    error = 0.0
    for neuron in network[i + 1]:
        print("neuron_adelante:", neuron)
        print(neuron['weights'][j])
# Out:
# neuron_adelante: {'weights': [-1.306117824465025, -2.0670118970079696, -1.6257166643661571, 8.341962100677772, -1.8423425412675547], 'output': 0.8163166539452361, 'delta': 0.18368334605476389}
# -1.306117824465025
# neuron_adelante: {'weights': [-1.306117824465025, -2.0670118970079696, -1.6257166643661571, 8.341962100677772, -1.8423425412675547], 'output': 0.8163166539452361, 'delta': 0.18368334605476389}
# -2.0670118970079696
# neuron_adelante: {'weights': [-1.306117824465025, -2.0670118970079696, -1.6257166643661571, 8.341962100677772, -1.8423425412675547], 'output': 0.8163166539452361, 'delta': 0.18368334605476389}
# -1.6257166643661571
# neuron_adelante: {'weights': [-1.306117824465025, -2.0670118970079696, -1.6257166643661571, 8.341962100677772, -1.8423425412675547], 'output': 0.8163166539452361, 'delta': 0.18368334605476389}
# 8.341962100677772

# %% [markdown]
# **Inicializando la red**
#
# initialize_network recibe el tamaño del vector de entrada, el número de capas ocultas y el numero de capas de salida.
#
# Si inicializamos initialize_network(2, 2, 1), tendremos 2 conjuntos de 2+1 pesos considerando el *bias* para la primera capa que asocia cada entrada de $[x_0,x_1]$ con cada neurona intermedia.

# %%
def initialize_network(n_inputs, n_hidden, n_outputs):
    network = list()
    hidden_layer = [{'weights':[random() for i in range(n_inputs + 1)]} for i in range(n_hidden)]
    network.append(hidden_layer)
    output_layer = [{'weights':[random() for i in range(n_hidden + 1)]} for i in range(n_outputs)]
    network.append(output_layer)
    return network

seed(1)
network = initialize_network(2, 2, 1)

print("capa de entrada:", network[0])

print("capa de salida:", network[1])
# Out:
# capa de entrada: [{'weights': [0.13436424411240122, 0.8474337369372327, 0.763774618976614]}, {'weights': [0.2550690257394217, 0.49543508709194095, 0.4494910647887381]}]
# capa de salida: [{'weights': [0.651592972722763, 0.7887233511355132, 0.0938595867742349]}]

# %% [markdown]
# La red está representada en un diccionario, donde la segunda capa tiene pesos asociados a cada entrada mas el "bias" o desplazamiento de la función en cada neurona. La tercera capa se conecta con la capa intermedia.
# ```
# capa de entrada: [{'weights': [0.13436424411240122, 0.8474337369372327, 0.763774618976614]},
#                   {'weights': [0.2550690257394217, 0.49543508709194095, 0.4494910647887381]}]
#
# capa de salida: [{'weights': [0.651592972722763, 0.7887233511355132, 0.0938595867742349]}]
# ```

# %% [markdown]
# **Propagación hacia adelante** (Forwad propagation): salida de la red neuronal dada una entrada $\mathbf{x}$
#
# Es la función que nos permite utilizar la red neuronal para hacer clasificación. La entrada se va procesando a través de las capas hasta obtener una salida.

# %% [markdown]
# **Activación de la neurona**
#
# Es el cálculo de una regresión lineal de la forma
#
# $$y = \mathbf{x}^T\mathbf{w} + w_0 $$

# %%
def activate(weights, inputs):
    # W'*X+w_0
    
    #bias: w_0
    activation = weights[-1]
    
    #calcular w_0 + W*X
    for i in range(len(weights)-1):
        activation += weights[i] * inputs[i]
        
    return activation

# %% [markdown]
# **Transferencia de la neurona**
#
# Existen muchas funciones de transferencia como relu, tanh identidad. Una de las mas utilizadas es la función sigmoide con forma de s, llamada curva logística. Tiene la forma:
#
# $$x = 1/(1+e^{-y}))$$

# %%
# Transfer neuron activation
def transfer(activation):
    return 1.0 / (1.0 + exp(-activation))

# %%
plt.plot(1/(1+np.exp(-np.arange(-10,10))))
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %% [markdown]
# **Propagación hacia adelante**
#
# Es la red neuronal en funcionamiento. Recibe una entrada $\mathbf{x_i}$ y regresa una salida $y_i$

# %%
# Propagación hacia adelante del computo de la entrada.
# Recibe la estructura de la red representada por un diccionario que contiene los pesos.

def forward_propagate(network, row):
    inputs = row
    for layer in network:
        new_inputs = []
        for neuron in layer:
            activation = activate(neuron['weights'], inputs)
            neuron['output'] = transfer(activation)
            new_inputs.append(neuron['output'])
        inputs = new_inputs
    return inputs

# %%
# Inventamos una red neuronal con la representación descrita
network = [
[{'weights': [0.13, 0.84, 0.76]},
 {'weights': [0.25, 0.49, 0.44]}],
    
 [{'weights': [0.65, 0.78, 0.09]}]]

#utilizamos un vector de entrada innventado
row = [1, 1]

#esta es la red en funcionamiento
output = forward_propagate(network, row)
print(output)
# Out:
# [0.7753511243987132]

# %%
# Se ha agregado lal diccionario la salida de cada capa
network
# Out:
# [[{'weights': [0.13, 0.84, 0.76], 'output': 0.8494124202541561},
#   {'weights': [0.25, 0.49, 0.44], 'output': 0.7649478037637647}],
#  [{'weights': [0.65, 0.78, 0.09], 'output': 0.7753511243987132}]]

# %% [markdown]
# **Derivada de transferencia hacia atrás de las capas intermedias**
#
# Esta derivada es válida siempre y cuando las neuronas tengas una función de transferencia sigmoidal. Es útil para calcular la derivada parcial de todos los pesos de la red.

# %%
# Esta es la derivada de la función sigmoide
def transfer_derivative(output):
    return output * (1.0 - output)

# %% [markdown]
# **Propagación hacia atrás del error**

# %%
 
# Propaga el error hacia atrás y lo va guardando en la estructura de la red
def backward_propagate_error(network, expected):
    
    #comenzamos con la capa de salida
    for i in reversed(range(len(network))):
        
        # por cada capa de la red asignada a layer
        layer = network[i]
        
        #el tamaño de la capa es equivalente al numero de neuronas en la capa
        n_neuronas = len(layer)
        
        #inicializamos error
        errors = list()
        
        # la primera vez calculamos sobre la ultima capa que es a la que tenemos acceso en un inicio
        if i == len(network)-1:
            
            # aquí se utiliza el error.
            
            # por cada neurona de la capa hacer:
            for j in range(n_neuronas):
                
                
                #asignamos la neurona j de la capa i
                neuron = layer[j]
                
                #asignamos la salida de la red neuronal previamente calculada
                yhat = neuron['output']
                
                #y será la salida real del conjunto de datos
                y = expected[0]
            
                #esta es la derivada de la función de costo basada en la log-verosimilitud
                # LL(\theta) = (y log yhat + (1-y) log [1-yhat])
                
                # Aqui comienza la transferencia, con la derivada de LL(\theta)
                e = (yhat-y)/((yhat-1)*yhat)
                errors.append(e)
        
        else:
            #aquí son las capas restantes hacia atrás donde propagamos el error
            
            for j in range(n_neuronas):
                error = 0.0
                for neuron in network[i + 1]:
                    error += (neuron['weights'][j] * neuron['delta'])
                errors.append(error)
                
        #aqui guardamos todos los delta asociada a cada neurona de cada capa
        for j in range(n_neuronas):
            neuron = layer[j]
            
            #el error magnifica el delta que depende de derivada de transferencia
            neuron['delta'] = errors[j] * transfer_derivative(neuron['output'])

# %%
backward_propagate_error(network, [3])

# %%
#Al propagar el error hacia atras se calculan los deltas o diferenciales de cada neurona
network
# Out:
# [[{'weights': [0.13, 0.84, 0.76],
#    'output': 0.8494124202541561,
#    'delta': 0.18496203349901957},
#   {'weights': [0.25, 0.49, 0.44],
#    'output': 0.7649478037637647,
#    'delta': 0.3119982748337181}],
#  [{'weights': [0.65, 0.78, 0.09],
#    'output': 0.7753511243987132,
#    'delta': 2.2246488756012868}]]

# %% [markdown]
# **Actualizar pesos con el error**
#
# Se recibe la red con los deltas, y un vector de entrada $row$ y la tasa de aprendizaje $l_rate$ asignada por el usuario la cual especifica en porcentaje de actualización que queremos para los pesos.

# %%
# Update network weights with error
def update_weights(network, row, l_rate):
    
    # por cada capa de la red
    for i in range(len(network)):
        
        #extraer la clasificación real del vector de entrada. 
        inputs = row[:-1]
        
        #las salidas ahora son las entradas de la siguiente capa
        if i != 0:
            inputs = [neuron['output'] for neuron in network[i - 1]]
 
        for neuron in network[i]:
            for j in range(len(inputs)):
                
                # por cada neurona y cada una de sus entradas
                neuron['weights'][j] += l_rate * neuron['delta'] * inputs[j]
            
            #actualización del bias
            neuron['weights'][-1] += l_rate * neuron['delta']

# %%
update_weights(network,[1,2,2],0.001)

# %%
#Se actualizan los pesos con los deltas.
network
# Out:
# [[{'weights': [0.13018496203349902, 0.840369924066998, 0.7601849620334991],
#    'output': 0.8494124202541561,
#    'delta': 0.18496203349901957},
#   {'weights': [0.2503119982748337, 0.49062399654966743, 0.4403119982748337],
#    'output': 0.7649478037637647,
#    'delta': 0.3119982748337181}],
#  [{'weights': [0.6518896443856402, 0.7817017402715367, 0.09222464887560128],
#    'output': 0.7753511243987132,
#    'delta': 2.2246488756012868}]]

# %% [markdown]
# **Entrenar la red con Gradiente Descendiente estocástico**
#
# * Se parece mucho al algoritmo de gradiente descendiente.
# Una característica diferente a Gradiente descendiente normal, es que por cada iteación, utiliza un vector de entrada diferente para actualizar los pesos.

# %%
#recibe 
# network: la red neuronal contenida en formato diccionario de pesos
# l_rate: tasa de aprendizaje, se recomienda que sea un numero pequeño menor a 1
# n_epoch: numero de iteraciones
# n_outputs:

def train_network(network, train, l_rate, n_epoch, n_outputs):
    for epoch in range(n_epoch):
        sum_error = 0
        
        #por cada vector en el conjunto de entrenamiento.
        for row in train:
            
            # se calcular la salida de un elemento del vector
            outputs = forward_propagate(network, row)
            
            #preparamos con ceros
            expected = [0 for i in range(n_outputs)]
    
            expected[0] = row[-1]
            
            #sumamos cada error en cada dimensión diferente
            
            #sum_error += sum([(expected[i]-outputs[i] )**2 for i in range(len(expected))])
            
            zi = expected[0]
            zi_e = outputs[0]
            
            #aquí el error reportado es la suma log verosimilitud , queremos que sea el máximo
            sum_error += zi*math.log(zi_e)+(1-zi)*math.log(1-zi_e)
        
            #print(expected)
            #propagamos hacia atrás 
            #el error generado por la diferencia de el valor esperado y el valor generado por la red
            # se reajusta la red para predecir mejor el valor esperado
            backward_propagate_error(network, expected)
            update_weights(network, row, l_rate)
        print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))

# %%
seed(1)


dataset = [[ 0.        , 43.57879291,  0.        ],
       [ 1.        , 38.25686159,  0.        ],
       [ 2.        , 33.65222425,  0.        ],
       [ 3.        , 35.58326609,  0.        ],
       [ 4.        , 34.71588722,  0.        ],
       [ 5.        , 32.38702072,  0.        ],
       [ 6.        , 28.39419039,  0.        ],
       [ 7.        , 20.20082333,  0.        ],
       [ 8.        , 24.19586975,  0.        ],
       [ 9.        , 18.48536939,  0.        ],
       [10.        , 19.43098795,  0.        ],
       [11.        ,  9.78931084,  0.        ],
       [12.        , 14.4403072 ,  0.        ],
       [13.        ,  8.95888303,  0.        ],
       [14.        ,  7.17704765,  0.        ],
       [15.        ,  9.57779397,  0.        ],
       [16.        ,  7.58424501,  0.        ],
       [17.        ,  8.9341588 ,  0.        ],
       [18.        ,  3.13378008,  0.        ],
       [19.        ,  9.23532406,  0.        ],
       [20.        ,  6.43370902,  0.        ],
       [21.        ,  6.67961846,  0.        ],
       [22.        ,  5.15107388,  0.        ],
       [23.        ,  3.13252828,  0.        ],
       [24.        ,  9.40036651,  0.        ],
       [25.        ,  8.96646931,  0.        ],
       [26.        , 12.97187713,  0.        ],
       [27.        ,  6.17097537,  0.        ],
       [28.        , 14.94380716,  0.        ],
       [29.        , 15.78038035,  0.        ],
       [30.        , 13.44006058,  0.        ],
       [31.        , 12.38640541,  0.        ],
       [32.        , 18.24681531,  0.        ],
       [33.        , 24.89568658,  0.        ],
       [34.        , 20.9740082 ,  0.        ],
       [35.        , 29.60592301,  0.        ],
       [36.        , 28.15828701,  0.        ],
       [37.        , 36.2793585 ,  0.        ],
       [38.        , 35.14373666,  0.        ],
       [39.        , 45.91909167,  0.        ],
       [ 0.        , 72.99963497,  1.        ],
       [ 1.        , 66.25249531,  1.        ],
       [ 2.        , 69.47862325,  1.        ],
       [ 3.        , 68.12423544,  1.        ],
       [ 4.        , 58.18406218,  1.        ],
       [ 5.        , 59.71572434,  1.        ],
       [ 6.        , 56.45457802,  1.        ],
       [ 7.        , 52.4068255 ,  1.        ],
       [ 8.        , 47.24274882,  1.        ],
       [ 9.        , 43.36311311,  1.        ],
       [10.        , 44.07483255,  1.        ],
       [11.        , 39.85302512,  1.        ],
       [12.        , 44.01192218,  1.        ],
       [13.        , 41.07318483,  1.        ],
       [14.        , 33.8127034 ,  1.        ],
       [15.        , 33.21045858,  1.        ],
       [16.        , 37.15741812,  1.        ],
       [17.        , 31.73730861,  1.        ],
       [18.        , 34.83305033,  1.        ],
       [19.        , 39.87419754,  1.        ],
       [20.        , 31.48844934,  1.        ],
       [21.        , 35.0882841 ,  1.        ],
       [22.        , 39.71262275,  1.        ],
       [23.        , 31.62777132,  1.        ],
       [24.        , 40.68066481,  1.        ],
       [25.        , 36.14619892,  1.        ],
       [26.        , 38.39007043,  1.        ],
       [27.        , 35.30625817,  1.        ],
       [28.        , 38.9855814 ,  1.        ],
       [29.        , 44.46375169,  1.        ],
       [30.        , 42.9567545 ,  1.        ],
       [31.        , 43.13876601,  1.        ],
       [32.        , 46.36785753,  1.        ],
       [33.        , 53.20209487,  1.        ],
       [34.        , 54.57671019,  1.        ],
       [35.        , 61.72180758,  1.        ],
       [36.        , 56.20328364,  1.        ],
       [37.        , 60.75140654,  1.        ],
       [38.        , 62.61155513,  1.        ],
       [39.        , 67.27858905,  1.        ]]

import numpy as np
import matplotlib.pyplot as plt
ds = np.array(dataset)

plt.scatter(ds[:40,0],ds[:40,1])
plt.scatter(ds[40:,0],ds[40:,1])

# %%
n_inputs = len(dataset[0]) - 1
print("inputs: ", n_inputs)

#total possible number of output values
n_outputs = len(set([ int(row[-1]) for row in dataset]))
n_outputs = 1 
print("outputs: ", n_outputs)
# Out:
# inputs:  2
# outputs:  1

# %%
network = initialize_network(n_inputs, 4, n_outputs)
train_network(network, dataset, 0.01, 1, n_outputs)

e = 0
for x in dataset:
    y = forward_propagate(network, x[:2])
    e+= (x[-1]- 1*((y[-1])>0.5))**2

print("errores:",e)
# Out:
# >epoch=0, lrate=0.010, error=-77.767
# errores: 40.0

# %%
train_network(network, dataset, 0.01, 5000, n_outputs)
for layer in network:
    print(layer)
# Out:
# >epoch=0, lrate=0.010, error=-61.422
# >epoch=1, lrate=0.010, error=-57.029
# >epoch=2, lrate=0.010, error=-55.768
# >epoch=3, lrate=0.010, error=-55.356
# >epoch=4, lrate=0.010, error=-55.210
# >epoch=5, lrate=0.010, error=-55.156
# >epoch=6, lrate=0.010, error=-55.135
# >epoch=7, lrate=0.010, error=-55.127
# >epoch=8, lrate=0.010, error=-55.123
# >epoch=9, lrate=0.010, error=-55.121
# >epoch=10, lrate=0.010, error=-55.120
# >epoch=11, lrate=0.010, error=-55.118
# >epoch=12, lrate=0.010, error=-55.116
# >epoch=13, lrate=0.010, error=-55.114
# >epoch=14, lrate=0.010, error=-55.112
# >epoch=15, lrate=0.010, error=-55.109
# >epoch=16, lrate=0.010, error=-55.105
# >epoch=17, lrate=0.010, error=-55.101
# >epoch=18, lrate=0.010, error=-55.095
# >epoch=19, lrate=0.010, error=-55.088
# >epoch=20, lrate=0.010, error=-55.077
# >epoch=21, lrate=0.010, error=-55.063
# >epoch=22, lrate=0.010, error=-55.042
# >epoch=23, lrate=0.010, error=-55.008
# >epoch=24, lrate=0.010, error=-54.954
# >epoch=25, lrate=0.010, error=-54.860
# >epoch=26, lrate=0.010, error=-54.696
# >epoch=27, lrate=0.010, error=-54.418
# >epoch=28, lrate=0.010, error=-53.854
# >epoch=29, lrate=0.010, error=-52.465
# >epoch=30, lrate=0.010, error=-50.606
# >epoch=31, lrate=0.010, error=-48.746
# >epoch=32, lrate=0.010, error=-47.284
# >epoch=33, lrate=0.010, error=-46.279
# >epoch=34, lrate=0.010, error=-45.456
# >epoch=35, lrate=0.010, error=-44.679
# >epoch=36, lrate=0.010, error=-43.933
# >epoch=37, lrate=0.010, error=-43.226
# >epoch=38, lrate=0.010, error=-42.558
# >epoch=39, lrate=0.010, error=-41.930
# >epoch=40, lrate=0.010, error=-41.338
# >epoch=41, lrate=0.010, error=-40.782
# >epoch=42, lrate=0.010, error=-40.257
# >epoch=43, lrate=0.010, error=-39.763
# >epoch=44, lrate=0.010, error=-39.297
# >epoch=45, lrate=0.010, error=-38.858
# >epoch=46, lrate=0.010, error=-38.443
# >epoch=47, lrate=0.010, error=-38.051
# >epoch=48, lrate=0.010, error=-37.680
# >epoch=49, lrate=0.010, error=-37.329
# >epoch=50, lrate=0.010, error=-36.996
# >epoch=51, lrate=0.010, error=-36.681
# >epoch=52, lrate=0.010, error=-36.382
# >epoch=53, lrate=0.010, error=-36.098
# >epoch=54, lrate=0.010, error=-35.828
# >epoch=55, lrate=0.010, error=-35.571
# >epoch=56, lrate=0.010, error=-35.326
# >epoch=57, lrate=0.010, error=-35.093
# >epoch=58, lrate=0.010, error=-34.871
# >epoch=59, lrate=0.010, error=-34.659
# >epoch=60, lrate=0.010, error=-34.456
# >epoch=61, lrate=0.010, error=-34.263
# >epoch=62, lrate=0.010, error=-34.078
# >epoch=63, lrate=0.010, error=-33.901
# >epoch=64, lrate=0.010, error=-33.731
# >epoch=65, lrate=0.010, error=-33.569
# >epoch=66, lrate=0.010, error=-33.413
# >epoch=67, lrate=0.010, error=-33.264
# >epoch=68, lrate=0.010, error=-33.121
# >epoch=69, lrate=0.010, error=-32.983
# >epoch=70, lrate=0.010, error=-32.851
# >epoch=71, lrate=0.010, error=-32.724
# >epoch=72, lrate=0.010, error=-32.602
# >epoch=73, lrate=0.010, error=-32.485
# >epoch=74, lrate=0.010, error=-32.371
# >epoch=75, lrate=0.010, error=-32.263
# >epoch=76, lrate=0.010, error=-32.158
# >epoch=77, lrate=0.010, error=-32.057
# >epoch=78, lrate=0.010, error=-31.959
# >epoch=79, lrate=0.010, error=-31.865
# >epoch=80, lrate=0.010, error=-31.774
# >epoch=81, lrate=0.010, error=-31.687
# >epoch=82, lrate=0.010, error=-31.602
# >epoch=83, lrate=0.010, error=-31.520
# >epoch=84, lrate=0.010, error=-31.441
# >epoch=85, lrate=0.010, error=-31.364
# >epoch=86, lrate=0.010, error=-31.290
# >epoch=87, lrate=0.010, error=-31.218
# >epoch=88, lrate=0.010, error=-31.148
# >epoch=89, lrate=0.010, error=-31.081
# >epoch=90, lrate=0.010, error=-31.015
# >epoch=91, lrate=0.010, error=-30.951
# >epoch=92, lrate=0.010, error=-30.890
# >epoch=93, lrate=0.010, error=-30.830
# >epoch=94, lrate=0.010, error=-30.772
# >epoch=95, lrate=0.010, error=-30.715
# >epoch=96, lrate=0.010, error=-30.660
# >epoch=97, lrate=0.010, error=-30.607
# >epoch=98, lrate=0.010, error=-30.555
# >epoch=99, lrate=0.010, error=-30.505
# >epoch=100, lrate=0.010, error=-30.455
# >epoch=101, lrate=0.010, error=-30.407
# >epoch=102, lrate=0.010, error=-30.361
# >epoch=103, lrate=0.010, error=-30.315
# >epoch=104, lrate=0.010, error=-30.271
# >epoch=105, lrate=0.010, error=-30.228
# >epoch=106, lrate=0.010, error=-30.186
# >epoch=107, lrate=0.010, error=-30.145
# >epoch=108, lrate=0.010, error=-30.104
# >epoch=109, lrate=0.010, error=-30.065
# >epoch=110, lrate=0.010, error=-30.027
# >epoch=111, lrate=0.010, error=-29.990
# >epoch=112, lrate=0.010, error=-29.953
# >epoch=113, lrate=0.010, error=-29.918
# >epoch=114, lrate=0.010, error=-29.883
# >epoch=115, lrate=0.010, error=-29.849
# >epoch=116, lrate=0.010, error=-29.815
# >epoch=117, lrate=0.010, error=-29.783
# >epoch=118, lrate=0.010, error=-29.751
# >epoch=119, lrate=0.010, error=-29.720
# >epoch=120, lrate=0.010, error=-29.689
# >epoch=121, lrate=0.010, error=-29.659
# >epoch=122, lrate=0.010, error=-29.630
# >epoch=123, lrate=0.010, error=-29.601
# >epoch=124, lrate=0.010, error=-29.573
# >epoch=125, lrate=0.010, error=-29.546
# >epoch=126, lrate=0.010, error=-29.519
# >epoch=127, lrate=0.010, error=-29.492
# >epoch=128, lrate=0.010, error=-29.467
# >epoch=129, lrate=0.010, error=-29.441
# >epoch=130, lrate=0.010, error=-29.416
# >epoch=131, lrate=0.010, error=-29.392
# >epoch=132, lrate=0.010, error=-29.368
# >epoch=133, lrate=0.010, error=-29.344
# >epoch=134, lrate=0.010, error=-29.321
# >epoch=135, lrate=0.010, error=-29.299
# >epoch=136, lrate=0.010, error=-29.276
# >epoch=137, lrate=0.010, error=-29.255
# >epoch=138, lrate=0.010, error=-29.233
# >epoch=139, lrate=0.010, error=-29.212
# >epoch=140, lrate=0.010, error=-29.191
# >epoch=141, lrate=0.010, error=-29.171
# >epoch=142, lrate=0.010, error=-29.151
# >epoch=143, lrate=0.010, error=-29.131
# >epoch=144, lrate=0.010, error=-29.112
# >epoch=145, lrate=0.010, error=-29.093
# >epoch=146, lrate=0.010, error=-29.075
# >epoch=147, lrate=0.010, error=-29.056
# >epoch=148, lrate=0.010, error=-29.038
# >epoch=149, lrate=0.010, error=-29.021
# >epoch=150, lrate=0.010, error=-29.003
# >epoch=151, lrate=0.010, error=-28.986
# >epoch=152, lrate=0.010, error=-28.969
# >epoch=153, lrate=0.010, error=-28.953
# >epoch=154, lrate=0.010, error=-28.937
# >epoch=155, lrate=0.010, error=-28.921
# >epoch=156, lrate=0.010, error=-28.905
# >epoch=157, lrate=0.010, error=-28.889
# >epoch=158, lrate=0.010, error=-28.874
# >epoch=159, lrate=0.010, error=-28.859
# >epoch=160, lrate=0.010, error=-28.844
# >epoch=161, lrate=0.010, error=-28.830
# >epoch=162, lrate=0.010, error=-28.815
# >epoch=163, lrate=0.010, error=-28.801
# >epoch=164, lrate=0.010, error=-28.787
# >epoch=165, lrate=0.010, error=-28.774
# >epoch=166, lrate=0.010, error=-28.760
# >epoch=167, lrate=0.010, error=-28.747
# >epoch=168, lrate=0.010, error=-28.734
# >epoch=169, lrate=0.010, error=-28.721
# >epoch=170, lrate=0.010, error=-28.708
# >epoch=171, lrate=0.010, error=-28.696
# >epoch=172, lrate=0.010, error=-28.684
# >epoch=173, lrate=0.010, error=-28.671
# >epoch=174, lrate=0.010, error=-28.659
# >epoch=175, lrate=0.010, error=-28.648
# >epoch=176, lrate=0.010, error=-28.636
# >epoch=177, lrate=0.010, error=-28.624
# >epoch=178, lrate=0.010, error=-28.613
# >epoch=179, lrate=0.010, error=-28.602
# >epoch=180, lrate=0.010, error=-28.591
# >epoch=181, lrate=0.010, error=-28.580
# >epoch=182, lrate=0.010, error=-28.569
# >epoch=183, lrate=0.010, error=-28.559
# >epoch=184, lrate=0.010, error=-28.548
# >epoch=185, lrate=0.010, error=-28.538
# >epoch=186, lrate=0.010, error=-28.528
# >epoch=187, lrate=0.010, error=-28.518
# >epoch=188, lrate=0.010, error=-28.508
# >epoch=189, lrate=0.010, error=-28.498
# >epoch=190, lrate=0.010, error=-28.488
# >epoch=191, lrate=0.010, error=-28.478
# >epoch=192, lrate=0.010, error=-28.469
# >epoch=193, lrate=0.010, error=-28.460
# >epoch=194, lrate=0.010, error=-28.450
# >epoch=195, lrate=0.010, error=-28.441
# >epoch=196, lrate=0.010, error=-28.432
# >epoch=197, lrate=0.010, error=-28.423
# >epoch=198, lrate=0.010, error=-28.414
# >epoch=199, lrate=0.010, error=-28.405
# >epoch=200, lrate=0.010, error=-28.397
# >epoch=201, lrate=0.010, error=-28.388
# >epoch=202, lrate=0.010, error=-28.379
# >epoch=203, lrate=0.010, error=-28.371
# >epoch=204, lrate=0.010, error=-28.363
# >epoch=205, lrate=0.010, error=-28.354
# >epoch=206, lrate=0.010, error=-28.346
# >epoch=207, lrate=0.010, error=-28.338
# >epoch=208, lrate=0.010, error=-28.330
# >epoch=209, lrate=0.010, error=-28.322
# >epoch=210, lrate=0.010, error=-28.314
# >epoch=211, lrate=0.010, error=-28.306
# >epoch=212, lrate=0.010, error=-28.299
# >epoch=213, lrate=0.010, error=-28.291
# >epoch=214, lrate=0.010, error=-28.283
# >epoch=215, lrate=0.010, error=-28.276
# >epoch=216, lrate=0.010, error=-28.268
# >epoch=217, lrate=0.010, error=-28.261
# >epoch=218, lrate=0.010, error=-28.253
# >epoch=219, lrate=0.010, error=-28.246
# >epoch=220, lrate=0.010, error=-28.239
# >epoch=221, lrate=0.010, error=-28.231
# >epoch=222, lrate=0.010, error=-28.224
# >epoch=223, lrate=0.010, error=-28.217
# >epoch=224, lrate=0.010, error=-28.210
# >epoch=225, lrate=0.010, error=-28.203
# >epoch=226, lrate=0.010, error=-28.196
# >epoch=227, lrate=0.010, error=-28.189
# >epoch=228, lrate=0.010, error=-28.182
# >epoch=229, lrate=0.010, error=-28.176
# >epoch=230, lrate=0.010, error=-28.169
# >epoch=231, lrate=0.010, error=-28.162
# >epoch=232, lrate=0.010, error=-28.156
# >epoch=233, lrate=0.010, error=-28.149
# >epoch=234, lrate=0.010, error=-28.142
# >epoch=235, lrate=0.010, error=-28.136
# >epoch=236, lrate=0.010, error=-28.129
# >epoch=237, lrate=0.010, error=-28.123
# >epoch=238, lrate=0.010, error=-28.116
# >epoch=239, lrate=0.010, error=-28.110
# >epoch=240, lrate=0.010, error=-28.104
# >epoch=241, lrate=0.010, error=-28.097
# >epoch=242, lrate=0.010, error=-28.091
# >epoch=243, lrate=0.010, error=-28.085
# >epoch=244, lrate=0.010, error=-28.079
# >epoch=245, lrate=0.010, error=-28.073
# >epoch=246, lrate=0.010, error=-28.066
# >epoch=247, lrate=0.010, error=-28.060
# >epoch=248, lrate=0.010, error=-28.054
# >epoch=249, lrate=0.010, error=-28.048
# >epoch=250, lrate=0.010, error=-28.042
# >epoch=251, lrate=0.010, error=-28.036
# >epoch=252, lrate=0.010, error=-28.030
# >epoch=253, lrate=0.010, error=-28.025
# >epoch=254, lrate=0.010, error=-28.019
# >epoch=255, lrate=0.010, error=-28.013
# >epoch=256, lrate=0.010, error=-28.007
# >epoch=257, lrate=0.010, error=-28.001
# >epoch=258, lrate=0.010, error=-27.995
# >epoch=259, lrate=0.010, error=-27.990
# >epoch=260, lrate=0.010, error=-27.984
# >epoch=261, lrate=0.010, error=-27.978
# >epoch=262, lrate=0.010, error=-27.973
# >epoch=263, lrate=0.010, error=-27.967
# >epoch=264, lrate=0.010, error=-27.962
# >epoch=265, lrate=0.010, error=-27.956
# >epoch=266, lrate=0.010, error=-27.951
# >epoch=267, lrate=0.010, error=-27.945
# >epoch=268, lrate=0.010, error=-27.940
# >epoch=269, lrate=0.010, error=-27.934
# >epoch=270, lrate=0.010, error=-27.929
# >epoch=271, lrate=0.010, error=-27.923
# >epoch=272, lrate=0.010, error=-27.918
# >epoch=273, lrate=0.010, error=-27.913
# >epoch=274, lrate=0.010, error=-27.907
# >epoch=275, lrate=0.010, error=-27.902
# >epoch=276, lrate=0.010, error=-27.897
# >epoch=277, lrate=0.010, error=-27.892
# >epoch=278, lrate=0.010, error=-27.886
# >epoch=279, lrate=0.010, error=-27.881
# >epoch=280, lrate=0.010, error=-27.876
# >epoch=281, lrate=0.010, error=-27.871
# >epoch=282, lrate=0.010, error=-27.866
# >epoch=283, lrate=0.010, error=-27.861
# >epoch=284, lrate=0.010, error=-27.856
# >epoch=285, lrate=0.010, error=-27.851
# >epoch=286, lrate=0.010, error=-27.845
# >epoch=287, lrate=0.010, error=-27.840
# >epoch=288, lrate=0.010, error=-27.836
# >epoch=289, lrate=0.010, error=-27.831
# >epoch=290, lrate=0.010, error=-27.826
# >epoch=291, lrate=0.010, error=-27.821
# >epoch=292, lrate=0.010, error=-27.816
# >epoch=293, lrate=0.010, error=-27.811
# >epoch=294, lrate=0.010, error=-27.806
# >epoch=295, lrate=0.010, error=-27.801
# >epoch=296, lrate=0.010, error=-27.797
# >epoch=297, lrate=0.010, error=-27.792
# >epoch=298, lrate=0.010, error=-27.787
# >epoch=299, lrate=0.010, error=-27.782
# >epoch=300, lrate=0.010, error=-27.778
# >epoch=301, lrate=0.010, error=-27.773
# >epoch=302, lrate=0.010, error=-27.768
# >epoch=303, lrate=0.010, error=-27.764
# >epoch=304, lrate=0.010, error=-27.759
# >epoch=305, lrate=0.010, error=-27.755
# >epoch=306, lrate=0.010, error=-27.750
# >epoch=307, lrate=0.010, error=-27.746
# >epoch=308, lrate=0.010, error=-27.741
# >epoch=309, lrate=0.010, error=-27.737
# >epoch=310, lrate=0.010, error=-27.732
# >epoch=311, lrate=0.010, error=-27.728
# >epoch=312, lrate=0.010, error=-27.723
# >epoch=313, lrate=0.010, error=-27.719
# >epoch=314, lrate=0.010, error=-27.715
# >epoch=315, lrate=0.010, error=-27.710
# >epoch=316, lrate=0.010, error=-27.706
# >epoch=317, lrate=0.010, error=-27.702
# >epoch=318, lrate=0.010, error=-27.698
# >epoch=319, lrate=0.010, error=-27.693
# >epoch=320, lrate=0.010, error=-27.689
# >epoch=321, lrate=0.010, error=-27.685
# >epoch=322, lrate=0.010, error=-27.681
# >epoch=323, lrate=0.010, error=-27.677
# >epoch=324, lrate=0.010, error=-27.673
# >epoch=325, lrate=0.010, error=-27.669
# >epoch=326, lrate=0.010, error=-27.665
# >epoch=327, lrate=0.010, error=-27.661
# >epoch=328, lrate=0.010, error=-27.657
# >epoch=329, lrate=0.010, error=-27.653
# >epoch=330, lrate=0.010, error=-27.649
# >epoch=331, lrate=0.010, error=-27.645
# >epoch=332, lrate=0.010, error=-27.641
# >epoch=333, lrate=0.010, error=-27.637
# >epoch=334, lrate=0.010, error=-27.633
# >epoch=335, lrate=0.010, error=-27.629
# >epoch=336, lrate=0.010, error=-27.625
# >epoch=337, lrate=0.010, error=-27.622
# >epoch=338, lrate=0.010, error=-27.618
# >epoch=339, lrate=0.010, error=-27.614
# >epoch=340, lrate=0.010, error=-27.610
# >epoch=341, lrate=0.010, error=-27.607
# >epoch=342, lrate=0.010, error=-27.603
# >epoch=343, lrate=0.010, error=-27.599
# >epoch=344, lrate=0.010, error=-27.596
# >epoch=345, lrate=0.010, error=-27.592
# >epoch=346, lrate=0.010, error=-27.589
# >epoch=347, lrate=0.010, error=-27.585
# >epoch=348, lrate=0.010, error=-27.582
# >epoch=349, lrate=0.010, error=-27.578
# >epoch=350, lrate=0.010, error=-27.575
# >epoch=351, lrate=0.010, error=-27.571
# >epoch=352, lrate=0.010, error=-27.568
# >epoch=353, lrate=0.010, error=-27.564
# >epoch=354, lrate=0.010, error=-27.561
# >epoch=355, lrate=0.010, error=-27.558
# >epoch=356, lrate=0.010, error=-27.554
# >epoch=357, lrate=0.010, error=-27.551
# >epoch=358, lrate=0.010, error=-27.548
# >epoch=359, lrate=0.010, error=-27.544
# >epoch=360, lrate=0.010, error=-27.541
# >epoch=361, lrate=0.010, error=-27.538
# >epoch=362, lrate=0.010, error=-27.535
# >epoch=363, lrate=0.010, error=-27.532
# >epoch=364, lrate=0.010, error=-27.528
# >epoch=365, lrate=0.010, error=-27.525
# >epoch=366, lrate=0.010, error=-27.522
# >epoch=367, lrate=0.010, error=-27.519
# >epoch=368, lrate=0.010, error=-27.516
# >epoch=369, lrate=0.010, error=-27.513
# >epoch=370, lrate=0.010, error=-27.510
# >epoch=371, lrate=0.010, error=-27.507
# >epoch=372, lrate=0.010, error=-27.504
# >epoch=373, lrate=0.010, error=-27.501
# >epoch=374, lrate=0.010, error=-27.498
# >epoch=375, lrate=0.010, error=-27.495
# >epoch=376, lrate=0.010, error=-27.492
# >epoch=377, lrate=0.010, error=-27.489
# >epoch=378, lrate=0.010, error=-27.486
# >epoch=379, lrate=0.010, error=-27.484
# >epoch=380, lrate=0.010, error=-27.481
# >epoch=381, lrate=0.010, error=-27.478
# >epoch=382, lrate=0.010, error=-27.475
# >epoch=383, lrate=0.010, error=-27.472
# >epoch=384, lrate=0.010, error=-27.470
# >epoch=385, lrate=0.010, error=-27.467
# >epoch=386, lrate=0.010, error=-27.464
# >epoch=387, lrate=0.010, error=-27.462
# >epoch=388, lrate=0.010, error=-27.459
# >epoch=389, lrate=0.010, error=-27.456
# >epoch=390, lrate=0.010, error=-27.454
# >epoch=391, lrate=0.010, error=-27.451
# >epoch=392, lrate=0.010, error=-27.448
# >epoch=393, lrate=0.010, error=-27.446
# >epoch=394, lrate=0.010, error=-27.443
# >epoch=395, lrate=0.010, error=-27.441
# >epoch=396, lrate=0.010, error=-27.438
# >epoch=397, lrate=0.010, error=-27.436
# >epoch=398, lrate=0.010, error=-27.433
# >epoch=399, lrate=0.010, error=-27.431
# >epoch=400, lrate=0.010, error=-27.428
# >epoch=401, lrate=0.010, error=-27.426
# >epoch=402, lrate=0.010, error=-27.423
# >epoch=403, lrate=0.010, error=-27.421
# >epoch=404, lrate=0.010, error=-27.418
# >epoch=405, lrate=0.010, error=-27.416
# >epoch=406, lrate=0.010, error=-27.414
# >epoch=407, lrate=0.010, error=-27.411
# >epoch=408, lrate=0.010, error=-27.409
# >epoch=409, lrate=0.010, error=-27.407
# >epoch=410, lrate=0.010, error=-27.404
# >epoch=411, lrate=0.010, error=-27.402
# >epoch=412, lrate=0.010, error=-27.400
# >epoch=413, lrate=0.010, error=-27.398
# >epoch=414, lrate=0.010, error=-27.395
# >epoch=415, lrate=0.010, error=-27.393
# >epoch=416, lrate=0.010, error=-27.391
# >epoch=417, lrate=0.010, error=-27.389
# >epoch=418, lrate=0.010, error=-27.387
# >epoch=419, lrate=0.010, error=-27.384
# >epoch=420, lrate=0.010, error=-27.382
# >epoch=421, lrate=0.010, error=-27.380
# >epoch=422, lrate=0.010, error=-27.378
# >epoch=423, lrate=0.010, error=-27.376
# >epoch=424, lrate=0.010, error=-27.374
# >epoch=425, lrate=0.010, error=-27.372
# >epoch=426, lrate=0.010, error=-27.370
# >epoch=427, lrate=0.010, error=-27.367
# >epoch=428, lrate=0.010, error=-27.365
# >epoch=429, lrate=0.010, error=-27.363
# >epoch=430, lrate=0.010, error=-27.361
# >epoch=431, lrate=0.010, error=-27.359
# >epoch=432, lrate=0.010, error=-27.357
# >epoch=433, lrate=0.010, error=-27.355
# >epoch=434, lrate=0.010, error=-27.353
# >epoch=435, lrate=0.010, error=-27.351
# >epoch=436, lrate=0.010, error=-27.350
# >epoch=437, lrate=0.010, error=-27.348
# >epoch=438, lrate=0.010, error=-27.346
# >epoch=439, lrate=0.010, error=-27.344
# >epoch=440, lrate=0.010, error=-27.342
# >epoch=441, lrate=0.010, error=-27.340
# >epoch=442, lrate=0.010, error=-27.338
# >epoch=443, lrate=0.010, error=-27.336
# >epoch=444, lrate=0.010, error=-27.334
# >epoch=445, lrate=0.010, error=-27.333
# >epoch=446, lrate=0.010, error=-27.331
# >epoch=447, lrate=0.010, error=-27.329
# >epoch=448, lrate=0.010, error=-27.327
# >epoch=449, lrate=0.010, error=-27.325
# >epoch=450, lrate=0.010, error=-27.324
# >epoch=451, lrate=0.010, error=-27.322
# >epoch=452, lrate=0.010, error=-27.320
# >epoch=453, lrate=0.010, error=-27.318
# >epoch=454, lrate=0.010, error=-27.317
# >epoch=455, lrate=0.010, error=-27.315
# >epoch=456, lrate=0.010, error=-27.313
# >epoch=457, lrate=0.010, error=-27.311
# >epoch=458, lrate=0.010, error=-27.310
# >epoch=459, lrate=0.010, error=-27.308
# >epoch=460, lrate=0.010, error=-27.306
# >epoch=461, lrate=0.010, error=-27.305
# >epoch=462, lrate=0.010, error=-27.303
# >epoch=463, lrate=0.010, error=-27.301
# >epoch=464, lrate=0.010, error=-27.300
# >epoch=465, lrate=0.010, error=-27.298
# >epoch=466, lrate=0.010, error=-27.296
# >epoch=467, lrate=0.010, error=-27.295
# >epoch=468, lrate=0.010, error=-27.293
# >epoch=469, lrate=0.010, error=-27.292
# >epoch=470, lrate=0.010, error=-27.290
# >epoch=471, lrate=0.010, error=-27.288
# >epoch=472, lrate=0.010, error=-27.287
# >epoch=473, lrate=0.010, error=-27.285
# >epoch=474, lrate=0.010, error=-27.284
# >epoch=475, lrate=0.010, error=-27.282
# >epoch=476, lrate=0.010, error=-27.281
# >epoch=477, lrate=0.010, error=-27.279
# >epoch=478, lrate=0.010, error=-27.278
# >epoch=479, lrate=0.010, error=-27.276
# >epoch=480, lrate=0.010, error=-27.275
# >epoch=481, lrate=0.010, error=-27.273
# >epoch=482, lrate=0.010, error=-27.272
# >epoch=483, lrate=0.010, error=-27.270
# >epoch=484, lrate=0.010, error=-27.269
# >epoch=485, lrate=0.010, error=-27.267
# >epoch=486, lrate=0.010, error=-27.266
# >epoch=487, lrate=0.010, error=-27.264
# >epoch=488, lrate=0.010, error=-27.263
# >epoch=489, lrate=0.010, error=-27.262
# >epoch=490, lrate=0.010, error=-27.260
# >epoch=491, lrate=0.010, error=-27.259
# >epoch=492, lrate=0.010, error=-27.257
# >epoch=493, lrate=0.010, error=-27.256
# >epoch=494, lrate=0.010, error=-27.255
# >epoch=495, lrate=0.010, error=-27.253
# >epoch=496, lrate=0.010, error=-27.252
# >epoch=497, lrate=0.010, error=-27.251
# >epoch=498, lrate=0.010, error=-27.249
# >epoch=499, lrate=0.010, error=-27.248
# >epoch=500, lrate=0.010, error=-27.246
# >epoch=501, lrate=0.010, error=-27.245
# >epoch=502, lrate=0.010, error=-27.244
# >epoch=503, lrate=0.010, error=-27.242
# >epoch=504, lrate=0.010, error=-27.241
# >epoch=505, lrate=0.010, error=-27.240
# >epoch=506, lrate=0.010, error=-27.239
# >epoch=507, lrate=0.010, error=-27.237
# >epoch=508, lrate=0.010, error=-27.236
# >epoch=509, lrate=0.010, error=-27.235
# >epoch=510, lrate=0.010, error=-27.233
# >epoch=511, lrate=0.010, error=-27.232
# >epoch=512, lrate=0.010, error=-27.231
# >epoch=513, lrate=0.010, error=-27.230
# >epoch=514, lrate=0.010, error=-27.228
# >epoch=515, lrate=0.010, error=-27.227
# >epoch=516, lrate=0.010, error=-27.226
# >epoch=517, lrate=0.010, error=-27.225
# >epoch=518, lrate=0.010, error=-27.224
# >epoch=519, lrate=0.010, error=-27.222
# >epoch=520, lrate=0.010, error=-27.221
# >epoch=521, lrate=0.010, error=-27.220
# >epoch=522, lrate=0.010, error=-27.219
# >epoch=523, lrate=0.010, error=-27.218
# >epoch=524, lrate=0.010, error=-27.216
# >epoch=525, lrate=0.010, error=-27.215
# >epoch=526, lrate=0.010, error=-27.214
# >epoch=527, lrate=0.010, error=-27.213
# >epoch=528, lrate=0.010, error=-27.212
# >epoch=529, lrate=0.010, error=-27.210
# >epoch=530, lrate=0.010, error=-27.209
# >epoch=531, lrate=0.010, error=-27.208
# >epoch=532, lrate=0.010, error=-27.207
# >epoch=533, lrate=0.010, error=-27.206
# >epoch=534, lrate=0.010, error=-27.205
# >epoch=535, lrate=0.010, error=-27.204
# >epoch=536, lrate=0.010, error=-27.203
# >epoch=537, lrate=0.010, error=-27.201
# >epoch=538, lrate=0.010, error=-27.200
# >epoch=539, lrate=0.010, error=-27.199
# >epoch=540, lrate=0.010, error=-27.198
# >epoch=541, lrate=0.010, error=-27.197
# >epoch=542, lrate=0.010, error=-27.196
# >epoch=543, lrate=0.010, error=-27.195
# >epoch=544, lrate=0.010, error=-27.194
# >epoch=545, lrate=0.010, error=-27.193
# >epoch=546, lrate=0.010, error=-27.192
# >epoch=547, lrate=0.010, error=-27.191
# >epoch=548, lrate=0.010, error=-27.190
# >epoch=549, lrate=0.010, error=-27.189
# >epoch=550, lrate=0.010, error=-27.188
# >epoch=551, lrate=0.010, error=-27.186
# >epoch=552, lrate=0.010, error=-27.185
# >epoch=553, lrate=0.010, error=-27.184
# >epoch=554, lrate=0.010, error=-27.183
# >epoch=555, lrate=0.010, error=-27.182
# >epoch=556, lrate=0.010, error=-27.181
# >epoch=557, lrate=0.010, error=-27.180
# >epoch=558, lrate=0.010, error=-27.179
# >epoch=559, lrate=0.010, error=-27.178
# >epoch=560, lrate=0.010, error=-27.177
# >epoch=561, lrate=0.010, error=-27.176
# >epoch=562, lrate=0.010, error=-27.175
# >epoch=563, lrate=0.010, error=-27.174
# >epoch=564, lrate=0.010, error=-27.173
# >epoch=565, lrate=0.010, error=-27.172
# >epoch=566, lrate=0.010, error=-27.171
# >epoch=567, lrate=0.010, error=-27.171
# >epoch=568, lrate=0.010, error=-27.170
# >epoch=569, lrate=0.010, error=-27.169
# >epoch=570, lrate=0.010, error=-27.168
# >epoch=571, lrate=0.010, error=-27.167
# >epoch=572, lrate=0.010, error=-27.166
# >epoch=573, lrate=0.010, error=-27.165
# >epoch=574, lrate=0.010, error=-27.164
# >epoch=575, lrate=0.010, error=-27.163
# >epoch=576, lrate=0.010, error=-27.162
# >epoch=577, lrate=0.010, error=-27.161
# >epoch=578, lrate=0.010, error=-27.160
# >epoch=579, lrate=0.010, error=-27.159
# >epoch=580, lrate=0.010, error=-27.158
# >epoch=581, lrate=0.010, error=-27.157
# >epoch=582, lrate=0.010, error=-27.157
# >epoch=583, lrate=0.010, error=-27.156
# >epoch=584, lrate=0.010, error=-27.155
# >epoch=585, lrate=0.010, error=-27.154
# >epoch=586, lrate=0.010, error=-27.153
# >epoch=587, lrate=0.010, error=-27.152
# >epoch=588, lrate=0.010, error=-27.151
# >epoch=589, lrate=0.010, error=-27.150
# >epoch=590, lrate=0.010, error=-27.149
# >epoch=591, lrate=0.010, error=-27.149
# >epoch=592, lrate=0.010, error=-27.148
# >epoch=593, lrate=0.010, error=-27.147
# >epoch=594, lrate=0.010, error=-27.146
# >epoch=595, lrate=0.010, error=-27.145
# >epoch=596, lrate=0.010, error=-27.144
# >epoch=597, lrate=0.010, error=-27.143
# >epoch=598, lrate=0.010, error=-27.143
# >epoch=599, lrate=0.010, error=-27.142
# >epoch=600, lrate=0.010, error=-27.141
# >epoch=601, lrate=0.010, error=-27.140
# >epoch=602, lrate=0.010, error=-27.139
# >epoch=603, lrate=0.010, error=-27.138
# >epoch=604, lrate=0.010, error=-27.138
# >epoch=605, lrate=0.010, error=-27.137
# >epoch=606, lrate=0.010, error=-27.136
# >epoch=607, lrate=0.010, error=-27.135
# >epoch=608, lrate=0.010, error=-27.134
# >epoch=609, lrate=0.010, error=-27.134
# >epoch=610, lrate=0.010, error=-27.133
# >epoch=611, lrate=0.010, error=-27.132
# >epoch=612, lrate=0.010, error=-27.131
# >epoch=613, lrate=0.010, error=-27.130
# >epoch=614, lrate=0.010, error=-27.130
# >epoch=615, lrate=0.010, error=-27.129
# >epoch=616, lrate=0.010, error=-27.128
# >epoch=617, lrate=0.010, error=-27.127
# >epoch=618, lrate=0.010, error=-27.127
# >epoch=619, lrate=0.010, error=-27.126
# >epoch=620, lrate=0.010, error=-27.125
# >epoch=621, lrate=0.010, error=-27.124
# >epoch=622, lrate=0.010, error=-27.123
# >epoch=623, lrate=0.010, error=-27.123
# >epoch=624, lrate=0.010, error=-27.122
# >epoch=625, lrate=0.010, error=-27.121
# >epoch=626, lrate=0.010, error=-27.120
# >epoch=627, lrate=0.010, error=-27.120
# >epoch=628, lrate=0.010, error=-27.119
# >epoch=629, lrate=0.010, error=-27.118
# >epoch=630, lrate=0.010, error=-27.117
# >epoch=631, lrate=0.010, error=-27.117
# >epoch=632, lrate=0.010, error=-27.116
# >epoch=633, lrate=0.010, error=-27.115
# >epoch=634, lrate=0.010, error=-27.115
# >epoch=635, lrate=0.010, error=-27.114
# >epoch=636, lrate=0.010, error=-27.113
# >epoch=637, lrate=0.010, error=-27.112
# >epoch=638, lrate=0.010, error=-27.112
# >epoch=639, lrate=0.010, error=-27.111
# >epoch=640, lrate=0.010, error=-27.110
# >epoch=641, lrate=0.010, error=-27.110
# >epoch=642, lrate=0.010, error=-27.109
# >epoch=643, lrate=0.010, error=-27.108
# >epoch=644, lrate=0.010, error=-27.107
# >epoch=645, lrate=0.010, error=-27.107
# >epoch=646, lrate=0.010, error=-27.106
# >epoch=647, lrate=0.010, error=-27.105
# >epoch=648, lrate=0.010, error=-27.105
# >epoch=649, lrate=0.010, error=-27.104
# >epoch=650, lrate=0.010, error=-27.103
# >epoch=651, lrate=0.010, error=-27.103
# >epoch=652, lrate=0.010, error=-27.102
# >epoch=653, lrate=0.010, error=-27.101
# >epoch=654, lrate=0.010, error=-27.101
# >epoch=655, lrate=0.010, error=-27.100
# >epoch=656, lrate=0.010, error=-27.099
# >epoch=657, lrate=0.010, error=-27.099
# >epoch=658, lrate=0.010, error=-27.098
# >epoch=659, lrate=0.010, error=-27.097
# >epoch=660, lrate=0.010, error=-27.097
# >epoch=661, lrate=0.010, error=-27.096
# >epoch=662, lrate=0.010, error=-27.095
# >epoch=663, lrate=0.010, error=-27.095
# >epoch=664, lrate=0.010, error=-27.094
# >epoch=665, lrate=0.010, error=-27.093
# >epoch=666, lrate=0.010, error=-27.093
# >epoch=667, lrate=0.010, error=-27.092
# >epoch=668, lrate=0.010, error=-27.091
# >epoch=669, lrate=0.010, error=-27.091
# >epoch=670, lrate=0.010, error=-27.090
# >epoch=671, lrate=0.010, error=-27.089
# >epoch=672, lrate=0.010, error=-27.089
# >epoch=673, lrate=0.010, error=-27.088
# >epoch=674, lrate=0.010, error=-27.088
# >epoch=675, lrate=0.010, error=-27.087
# >epoch=676, lrate=0.010, error=-27.086
# >epoch=677, lrate=0.010, error=-27.086
# >epoch=678, lrate=0.010, error=-27.085
# >epoch=679, lrate=0.010, error=-27.085
# >epoch=680, lrate=0.010, error=-27.084
# >epoch=681, lrate=0.010, error=-27.083
# >epoch=682, lrate=0.010, error=-27.083
# >epoch=683, lrate=0.010, error=-27.082
# >epoch=684, lrate=0.010, error=-27.081
# >epoch=685, lrate=0.010, error=-27.081
# >epoch=686, lrate=0.010, error=-27.080
# >epoch=687, lrate=0.010, error=-27.080
# >epoch=688, lrate=0.010, error=-27.079
# >epoch=689, lrate=0.010, error=-27.078
# >epoch=690, lrate=0.010, error=-27.078
# >epoch=691, lrate=0.010, error=-27.077
# >epoch=692, lrate=0.010, error=-27.077
# >epoch=693, lrate=0.010, error=-27.076
# >epoch=694, lrate=0.010, error=-27.076
# >epoch=695, lrate=0.010, error=-27.075
# >epoch=696, lrate=0.010, error=-27.074
# >epoch=697, lrate=0.010, error=-27.074
# >epoch=698, lrate=0.010, error=-27.073
# >epoch=699, lrate=0.010, error=-27.073
# >epoch=700, lrate=0.010, error=-27.072
# >epoch=701, lrate=0.010, error=-27.072
# >epoch=702, lrate=0.010, error=-27.071
# >epoch=703, lrate=0.010, error=-27.070
# >epoch=704, lrate=0.010, error=-27.070
# >epoch=705, lrate=0.010, error=-27.069
# >epoch=706, lrate=0.010, error=-27.069
# >epoch=707, lrate=0.010, error=-27.068
# >epoch=708, lrate=0.010, error=-27.068
# >epoch=709, lrate=0.010, error=-27.067
# >epoch=710, lrate=0.010, error=-27.067
# >epoch=711, lrate=0.010, error=-27.066
# >epoch=712, lrate=0.010, error=-27.065
# >epoch=713, lrate=0.010, error=-27.065
# >epoch=714, lrate=0.010, error=-27.064
# >epoch=715, lrate=0.010, error=-27.064
# >epoch=716, lrate=0.010, error=-27.063
# >epoch=717, lrate=0.010, error=-27.063
# >epoch=718, lrate=0.010, error=-27.062
# >epoch=719, lrate=0.010, error=-27.062
# >epoch=720, lrate=0.010, error=-27.061
# >epoch=721, lrate=0.010, error=-27.061
# >epoch=722, lrate=0.010, error=-27.060
# >epoch=723, lrate=0.010, error=-27.060
# >epoch=724, lrate=0.010, error=-27.059
# >epoch=725, lrate=0.010, error=-27.058
# >epoch=726, lrate=0.010, error=-27.058
# >epoch=727, lrate=0.010, error=-27.057
# >epoch=728, lrate=0.010, error=-27.057
# >epoch=729, lrate=0.010, error=-27.056
# >epoch=730, lrate=0.010, error=-27.056
# >epoch=731, lrate=0.010, error=-27.055
# >epoch=732, lrate=0.010, error=-27.055
# >epoch=733, lrate=0.010, error=-27.054
# >epoch=734, lrate=0.010, error=-27.054
# >epoch=735, lrate=0.010, error=-27.053
# >epoch=736, lrate=0.010, error=-27.053
# >epoch=737, lrate=0.010, error=-27.052
# >epoch=738, lrate=0.010, error=-27.052
# >epoch=739, lrate=0.010, error=-27.051
# >epoch=740, lrate=0.010, error=-27.051
# >epoch=741, lrate=0.010, error=-27.050
# >epoch=742, lrate=0.010, error=-27.050
# >epoch=743, lrate=0.010, error=-27.049
# >epoch=744, lrate=0.010, error=-27.049
# >epoch=745, lrate=0.010, error=-27.048
# >epoch=746, lrate=0.010, error=-27.048
# >epoch=747, lrate=0.010, error=-27.047
# >epoch=748, lrate=0.010, error=-27.047
# >epoch=749, lrate=0.010, error=-27.046
# >epoch=750, lrate=0.010, error=-27.046
# >epoch=751, lrate=0.010, error=-27.045
# >epoch=752, lrate=0.010, error=-27.045
# >epoch=753, lrate=0.010, error=-27.044
# >epoch=754, lrate=0.010, error=-27.044
# >epoch=755, lrate=0.010, error=-27.044
# >epoch=756, lrate=0.010, error=-27.043
# >epoch=757, lrate=0.010, error=-27.043
# >epoch=758, lrate=0.010, error=-27.042
# >epoch=759, lrate=0.010, error=-27.042
# >epoch=760, lrate=0.010, error=-27.041
# >epoch=761, lrate=0.010, error=-27.041
# >epoch=762, lrate=0.010, error=-27.040
# >epoch=763, lrate=0.010, error=-27.040
# >epoch=764, lrate=0.010, error=-27.039
# >epoch=765, lrate=0.010, error=-27.039
# >epoch=766, lrate=0.010, error=-27.038
# >epoch=767, lrate=0.010, error=-27.038
# >epoch=768, lrate=0.010, error=-27.037
# >epoch=769, lrate=0.010, error=-27.037
# >epoch=770, lrate=0.010, error=-27.037
# >epoch=771, lrate=0.010, error=-27.036
# >epoch=772, lrate=0.010, error=-27.036
# >epoch=773, lrate=0.010, error=-27.035
# >epoch=774, lrate=0.010, error=-27.035
# >epoch=775, lrate=0.010, error=-27.034
# >epoch=776, lrate=0.010, error=-27.034
# >epoch=777, lrate=0.010, error=-27.033
# >epoch=778, lrate=0.010, error=-27.033
# >epoch=779, lrate=0.010, error=-27.033
# >epoch=780, lrate=0.010, error=-27.032
# >epoch=781, lrate=0.010, error=-27.032
# >epoch=782, lrate=0.010, error=-27.031
# >epoch=783, lrate=0.010, error=-27.031
# >epoch=784, lrate=0.010, error=-27.030
# >epoch=785, lrate=0.010, error=-27.030
# >epoch=786, lrate=0.010, error=-27.029
# >epoch=787, lrate=0.010, error=-27.029
# >epoch=788, lrate=0.010, error=-27.029
# >epoch=789, lrate=0.010, error=-27.028
# >epoch=790, lrate=0.010, error=-27.028
# >epoch=791, lrate=0.010, error=-27.027
# >epoch=792, lrate=0.010, error=-27.027
# >epoch=793, lrate=0.010, error=-27.026
# >epoch=794, lrate=0.010, error=-27.026
# >epoch=795, lrate=0.010, error=-27.026
# >epoch=796, lrate=0.010, error=-27.025
# >epoch=797, lrate=0.010, error=-27.025
# >epoch=798, lrate=0.010, error=-27.024
# >epoch=799, lrate=0.010, error=-27.024
# >epoch=800, lrate=0.010, error=-27.024
# >epoch=801, lrate=0.010, error=-27.023
# >epoch=802, lrate=0.010, error=-27.023
# >epoch=803, lrate=0.010, error=-27.022
# >epoch=804, lrate=0.010, error=-27.022
# >epoch=805, lrate=0.010, error=-27.022
# >epoch=806, lrate=0.010, error=-27.021
# >epoch=807, lrate=0.010, error=-27.021
# >epoch=808, lrate=0.010, error=-27.020
# >epoch=809, lrate=0.010, error=-27.020
# >epoch=810, lrate=0.010, error=-27.019
# >epoch=811, lrate=0.010, error=-27.019
# >epoch=812, lrate=0.010, error=-27.019
# >epoch=813, lrate=0.010, error=-27.018
# >epoch=814, lrate=0.010, error=-27.018
# >epoch=815, lrate=0.010, error=-27.017
# >epoch=816, lrate=0.010, error=-27.017
# >epoch=817, lrate=0.010, error=-27.017
# >epoch=818, lrate=0.010, error=-27.016
# >epoch=819, lrate=0.010, error=-27.016
# >epoch=820, lrate=0.010, error=-27.016
# >epoch=821, lrate=0.010, error=-27.015
# >epoch=822, lrate=0.010, error=-27.015
# >epoch=823, lrate=0.010, error=-27.014
# >epoch=824, lrate=0.010, error=-27.014
# >epoch=825, lrate=0.010, error=-27.014
# >epoch=826, lrate=0.010, error=-27.013
# >epoch=827, lrate=0.010, error=-27.013
# >epoch=828, lrate=0.010, error=-27.012
# >epoch=829, lrate=0.010, error=-27.012
# >epoch=830, lrate=0.010, error=-27.012
# >epoch=831, lrate=0.010, error=-27.011
# >epoch=832, lrate=0.010, error=-27.011
# >epoch=833, lrate=0.010, error=-27.011
# >epoch=834, lrate=0.010, error=-27.010
# >epoch=835, lrate=0.010, error=-27.010
# >epoch=836, lrate=0.010, error=-27.009
# >epoch=837, lrate=0.010, error=-27.009
# >epoch=838, lrate=0.010, error=-27.009
# >epoch=839, lrate=0.010, error=-27.008
# >epoch=840, lrate=0.010, error=-27.008
# >epoch=841, lrate=0.010, error=-27.008
# >epoch=842, lrate=0.010, error=-27.007
# >epoch=843, lrate=0.010, error=-27.007
# >epoch=844, lrate=0.010, error=-27.006
# >epoch=845, lrate=0.010, error=-27.006
# >epoch=846, lrate=0.010, error=-27.006
# >epoch=847, lrate=0.010, error=-27.005
# >epoch=848, lrate=0.010, error=-27.005
# >epoch=849, lrate=0.010, error=-27.005
# >epoch=850, lrate=0.010, error=-27.004
# >epoch=851, lrate=0.010, error=-27.004
# >epoch=852, lrate=0.010, error=-27.004
# >epoch=853, lrate=0.010, error=-27.003
# >epoch=854, lrate=0.010, error=-27.003
# >epoch=855, lrate=0.010, error=-27.003
# >epoch=856, lrate=0.010, error=-27.002
# >epoch=857, lrate=0.010, error=-27.002
# >epoch=858, lrate=0.010, error=-27.001
# >epoch=859, lrate=0.010, error=-27.001
# >epoch=860, lrate=0.010, error=-27.001
# >epoch=861, lrate=0.010, error=-27.000
# >epoch=862, lrate=0.010, error=-27.000
# >epoch=863, lrate=0.010, error=-27.000
# >epoch=864, lrate=0.010, error=-26.999
# >epoch=865, lrate=0.010, error=-26.999
# >epoch=866, lrate=0.010, error=-26.999
# >epoch=867, lrate=0.010, error=-26.998
# >epoch=868, lrate=0.010, error=-26.998
# >epoch=869, lrate=0.010, error=-26.998
# >epoch=870, lrate=0.010, error=-26.997
# >epoch=871, lrate=0.010, error=-26.997
# >epoch=872, lrate=0.010, error=-26.997
# >epoch=873, lrate=0.010, error=-26.996
# >epoch=874, lrate=0.010, error=-26.996
# >epoch=875, lrate=0.010, error=-26.996
# >epoch=876, lrate=0.010, error=-26.995
# >epoch=877, lrate=0.010, error=-26.995
# >epoch=878, lrate=0.010, error=-26.995
# >epoch=879, lrate=0.010, error=-26.994
# >epoch=880, lrate=0.010, error=-26.994
# >epoch=881, lrate=0.010, error=-26.994
# >epoch=882, lrate=0.010, error=-26.993
# >epoch=883, lrate=0.010, error=-26.993
# >epoch=884, lrate=0.010, error=-26.993
# >epoch=885, lrate=0.010, error=-26.992
# >epoch=886, lrate=0.010, error=-26.992
# >epoch=887, lrate=0.010, error=-26.992
# >epoch=888, lrate=0.010, error=-26.991
# >epoch=889, lrate=0.010, error=-26.991
# >epoch=890, lrate=0.010, error=-26.991
# >epoch=891, lrate=0.010, error=-26.990
# >epoch=892, lrate=0.010, error=-26.990
# >epoch=893, lrate=0.010, error=-26.990
# >epoch=894, lrate=0.010, error=-26.989
# >epoch=895, lrate=0.010, error=-26.989
# >epoch=896, lrate=0.010, error=-26.989
# >epoch=897, lrate=0.010, error=-26.988
# >epoch=898, lrate=0.010, error=-26.988
# >epoch=899, lrate=0.010, error=-26.988
# >epoch=900, lrate=0.010, error=-26.987
# >epoch=901, lrate=0.010, error=-26.987
# >epoch=902, lrate=0.010, error=-26.987
# >epoch=903, lrate=0.010, error=-26.987
# >epoch=904, lrate=0.010, error=-26.986
# >epoch=905, lrate=0.010, error=-26.986
# >epoch=906, lrate=0.010, error=-26.986
# >epoch=907, lrate=0.010, error=-26.985
# >epoch=908, lrate=0.010, error=-26.985
# >epoch=909, lrate=0.010, error=-26.985
# >epoch=910, lrate=0.010, error=-26.984
# >epoch=911, lrate=0.010, error=-26.984
# >epoch=912, lrate=0.010, error=-26.984
# >epoch=913, lrate=0.010, error=-26.983
# >epoch=914, lrate=0.010, error=-26.983
# >epoch=915, lrate=0.010, error=-26.983
# >epoch=916, lrate=0.010, error=-26.983
# >epoch=917, lrate=0.010, error=-26.982
# >epoch=918, lrate=0.010, error=-26.982
# >epoch=919, lrate=0.010, error=-26.982
# >epoch=920, lrate=0.010, error=-26.981
# >epoch=921, lrate=0.010, error=-26.981
# >epoch=922, lrate=0.010, error=-26.981
# >epoch=923, lrate=0.010, error=-26.980
# >epoch=924, lrate=0.010, error=-26.980
# >epoch=925, lrate=0.010, error=-26.980
# >epoch=926, lrate=0.010, error=-26.980
# >epoch=927, lrate=0.010, error=-26.979
# >epoch=928, lrate=0.010, error=-26.979
# >epoch=929, lrate=0.010, error=-26.979
# >epoch=930, lrate=0.010, error=-26.978
# >epoch=931, lrate=0.010, error=-26.978
# >epoch=932, lrate=0.010, error=-26.978
# >epoch=933, lrate=0.010, error=-26.978
# >epoch=934, lrate=0.010, error=-26.977
# >epoch=935, lrate=0.010, error=-26.977
# >epoch=936, lrate=0.010, error=-26.977
# >epoch=937, lrate=0.010, error=-26.976
# >epoch=938, lrate=0.010, error=-26.976
# >epoch=939, lrate=0.010, error=-26.976
# >epoch=940, lrate=0.010, error=-26.975
# >epoch=941, lrate=0.010, error=-26.975
# >epoch=942, lrate=0.010, error=-26.975
# >epoch=943, lrate=0.010, error=-26.975
# >epoch=944, lrate=0.010, error=-26.974
# >epoch=945, lrate=0.010, error=-26.974
# >epoch=946, lrate=0.010, error=-26.974
# >epoch=947, lrate=0.010, error=-26.974
# >epoch=948, lrate=0.010, error=-26.973
# >epoch=949, lrate=0.010, error=-26.973
# >epoch=950, lrate=0.010, error=-26.973
# >epoch=951, lrate=0.010, error=-26.972
# >epoch=952, lrate=0.010, error=-26.972
# >epoch=953, lrate=0.010, error=-26.972
# >epoch=954, lrate=0.010, error=-26.972
# >epoch=955, lrate=0.010, error=-26.971
# >epoch=956, lrate=0.010, error=-26.971
# >epoch=957, lrate=0.010, error=-26.971
# >epoch=958, lrate=0.010, error=-26.970
# >epoch=959, lrate=0.010, error=-26.970
# >epoch=960, lrate=0.010, error=-26.970
# >epoch=961, lrate=0.010, error=-26.970
# >epoch=962, lrate=0.010, error=-26.969
# >epoch=963, lrate=0.010, error=-26.969
# >epoch=964, lrate=0.010, error=-26.969
# >epoch=965, lrate=0.010, error=-26.969
# >epoch=966, lrate=0.010, error=-26.968
# >epoch=967, lrate=0.010, error=-26.968
# >epoch=968, lrate=0.010, error=-26.968
# >epoch=969, lrate=0.010, error=-26.968
# >epoch=970, lrate=0.010, error=-26.967
# >epoch=971, lrate=0.010, error=-26.967
# >epoch=972, lrate=0.010, error=-26.967
# >epoch=973, lrate=0.010, error=-26.966
# >epoch=974, lrate=0.010, error=-26.966
# >epoch=975, lrate=0.010, error=-26.966
# >epoch=976, lrate=0.010, error=-26.966
# >epoch=977, lrate=0.010, error=-26.965
# >epoch=978, lrate=0.010, error=-26.965
# >epoch=979, lrate=0.010, error=-26.965
# >epoch=980, lrate=0.010, error=-26.965
# >epoch=981, lrate=0.010, error=-26.964
# >epoch=982, lrate=0.010, error=-26.964
# >epoch=983, lrate=0.010, error=-26.964
# >epoch=984, lrate=0.010, error=-26.964
# >epoch=985, lrate=0.010, error=-26.963
# >epoch=986, lrate=0.010, error=-26.963
# >epoch=987, lrate=0.010, error=-26.963
# >epoch=988, lrate=0.010, error=-26.963
# >epoch=989, lrate=0.010, error=-26.962
# >epoch=990, lrate=0.010, error=-26.962
# >epoch=991, lrate=0.010, error=-26.962
# >epoch=992, lrate=0.010, error=-26.962
# >epoch=993, lrate=0.010, error=-26.961
# >epoch=994, lrate=0.010, error=-26.961
# >epoch=995, lrate=0.010, error=-26.961
# >epoch=996, lrate=0.010, error=-26.961
# >epoch=997, lrate=0.010, error=-26.960
# >epoch=998, lrate=0.010, error=-26.960
# >epoch=999, lrate=0.010, error=-26.960
# >epoch=1000, lrate=0.010, error=-26.960
# >epoch=1001, lrate=0.010, error=-26.959
# >epoch=1002, lrate=0.010, error=-26.959
# >epoch=1003, lrate=0.010, error=-26.959
# >epoch=1004, lrate=0.010, error=-26.959
# >epoch=1005, lrate=0.010, error=-26.958
# >epoch=1006, lrate=0.010, error=-26.958
# >epoch=1007, lrate=0.010, error=-26.958
# >epoch=1008, lrate=0.010, error=-26.958
# >epoch=1009, lrate=0.010, error=-26.957
# >epoch=1010, lrate=0.010, error=-26.957
# >epoch=1011, lrate=0.010, error=-26.957
# >epoch=1012, lrate=0.010, error=-26.957
# >epoch=1013, lrate=0.010, error=-26.956
# >epoch=1014, lrate=0.010, error=-26.956
# >epoch=1015, lrate=0.010, error=-26.956
# >epoch=1016, lrate=0.010, error=-26.956
# >epoch=1017, lrate=0.010, error=-26.955
# >epoch=1018, lrate=0.010, error=-26.955
# >epoch=1019, lrate=0.010, error=-26.955
# >epoch=1020, lrate=0.010, error=-26.955
# >epoch=1021, lrate=0.010, error=-26.954
# >epoch=1022, lrate=0.010, error=-26.954
# >epoch=1023, lrate=0.010, error=-26.954
# >epoch=1024, lrate=0.010, error=-26.954
# >epoch=1025, lrate=0.010, error=-26.954
# >epoch=1026, lrate=0.010, error=-26.953
# >epoch=1027, lrate=0.010, error=-26.953
# >epoch=1028, lrate=0.010, error=-26.953
# >epoch=1029, lrate=0.010, error=-26.953
# >epoch=1030, lrate=0.010, error=-26.952
# >epoch=1031, lrate=0.010, error=-26.952
# >epoch=1032, lrate=0.010, error=-26.952
# >epoch=1033, lrate=0.010, error=-26.952
# >epoch=1034, lrate=0.010, error=-26.951
# >epoch=1035, lrate=0.010, error=-26.951
# >epoch=1036, lrate=0.010, error=-26.951
# >epoch=1037, lrate=0.010, error=-26.951
# >epoch=1038, lrate=0.010, error=-26.951
# >epoch=1039, lrate=0.010, error=-26.950
# >epoch=1040, lrate=0.010, error=-26.950
# >epoch=1041, lrate=0.010, error=-26.950
# >epoch=1042, lrate=0.010, error=-26.950
# >epoch=1043, lrate=0.010, error=-26.949
# >epoch=1044, lrate=0.010, error=-26.949
# >epoch=1045, lrate=0.010, error=-26.949
# >epoch=1046, lrate=0.010, error=-26.949
# >epoch=1047, lrate=0.010, error=-26.949
# >epoch=1048, lrate=0.010, error=-26.948
# >epoch=1049, lrate=0.010, error=-26.948
# >epoch=1050, lrate=0.010, error=-26.948
# >epoch=1051, lrate=0.010, error=-26.948
# >epoch=1052, lrate=0.010, error=-26.947
# >epoch=1053, lrate=0.010, error=-26.947
# >epoch=1054, lrate=0.010, error=-26.947
# >epoch=1055, lrate=0.010, error=-26.947
# >epoch=1056, lrate=0.010, error=-26.947
# >epoch=1057, lrate=0.010, error=-26.946
# >epoch=1058, lrate=0.010, error=-26.946
# >epoch=1059, lrate=0.010, error=-26.946
# >epoch=1060, lrate=0.010, error=-26.946
# >epoch=1061, lrate=0.010, error=-26.945
# >epoch=1062, lrate=0.010, error=-26.945
# >epoch=1063, lrate=0.010, error=-26.945
# >epoch=1064, lrate=0.010, error=-26.945
# >epoch=1065, lrate=0.010, error=-26.945
# >epoch=1066, lrate=0.010, error=-26.944
# >epoch=1067, lrate=0.010, error=-26.944
# >epoch=1068, lrate=0.010, error=-26.944
# >epoch=1069, lrate=0.010, error=-26.944
# >epoch=1070, lrate=0.010, error=-26.944
# >epoch=1071, lrate=0.010, error=-26.943
# >epoch=1072, lrate=0.010, error=-26.943
# >epoch=1073, lrate=0.010, error=-26.943
# >epoch=1074, lrate=0.010, error=-26.943
# >epoch=1075, lrate=0.010, error=-26.942
# >epoch=1076, lrate=0.010, error=-26.942
# >epoch=1077, lrate=0.010, error=-26.942
# >epoch=1078, lrate=0.010, error=-26.942
# >epoch=1079, lrate=0.010, error=-26.942
# >epoch=1080, lrate=0.010, error=-26.941
# >epoch=1081, lrate=0.010, error=-26.941
# >epoch=1082, lrate=0.010, error=-26.941
# >epoch=1083, lrate=0.010, error=-26.941
# >epoch=1084, lrate=0.010, error=-26.941
# >epoch=1085, lrate=0.010, error=-26.940
# >epoch=1086, lrate=0.010, error=-26.940
# >epoch=1087, lrate=0.010, error=-26.940
# >epoch=1088, lrate=0.010, error=-26.940
# >epoch=1089, lrate=0.010, error=-26.940
# >epoch=1090, lrate=0.010, error=-26.939
# >epoch=1091, lrate=0.010, error=-26.939
# >epoch=1092, lrate=0.010, error=-26.939
# >epoch=1093, lrate=0.010, error=-26.939
# >epoch=1094, lrate=0.010, error=-26.939
# >epoch=1095, lrate=0.010, error=-26.938
# >epoch=1096, lrate=0.010, error=-26.938
# >epoch=1097, lrate=0.010, error=-26.938
# >epoch=1098, lrate=0.010, error=-26.938
# >epoch=1099, lrate=0.010, error=-26.938
# >epoch=1100, lrate=0.010, error=-26.937
# >epoch=1101, lrate=0.010, error=-26.937
# >epoch=1102, lrate=0.010, error=-26.937
# >epoch=1103, lrate=0.010, error=-26.937
# >epoch=1104, lrate=0.010, error=-26.937
# >epoch=1105, lrate=0.010, error=-26.936
# >epoch=1106, lrate=0.010, error=-26.936
# >epoch=1107, lrate=0.010, error=-26.936
# >epoch=1108, lrate=0.010, error=-26.936
# >epoch=1109, lrate=0.010, error=-26.936
# >epoch=1110, lrate=0.010, error=-26.935
# >epoch=1111, lrate=0.010, error=-26.935
# >epoch=1112, lrate=0.010, error=-26.935
# >epoch=1113, lrate=0.010, error=-26.935
# >epoch=1114, lrate=0.010, error=-26.935
# >epoch=1115, lrate=0.010, error=-26.934
# >epoch=1116, lrate=0.010, error=-26.934
# >epoch=1117, lrate=0.010, error=-26.934
# >epoch=1118, lrate=0.010, error=-26.934
# >epoch=1119, lrate=0.010, error=-26.934
# >epoch=1120, lrate=0.010, error=-26.933
# >epoch=1121, lrate=0.010, error=-26.933
# >epoch=1122, lrate=0.010, error=-26.933
# >epoch=1123, lrate=0.010, error=-26.933
# >epoch=1124, lrate=0.010, error=-26.933
# >epoch=1125, lrate=0.010, error=-26.932
# >epoch=1126, lrate=0.010, error=-26.932
# >epoch=1127, lrate=0.010, error=-26.932
# >epoch=1128, lrate=0.010, error=-26.932
# >epoch=1129, lrate=0.010, error=-26.932
# >epoch=1130, lrate=0.010, error=-26.932
# >epoch=1131, lrate=0.010, error=-26.931
# >epoch=1132, lrate=0.010, error=-26.931
# >epoch=1133, lrate=0.010, error=-26.931
# >epoch=1134, lrate=0.010, error=-26.931
# >epoch=1135, lrate=0.010, error=-26.931
# >epoch=1136, lrate=0.010, error=-26.930
# >epoch=1137, lrate=0.010, error=-26.930
# >epoch=1138, lrate=0.010, error=-26.930
# >epoch=1139, lrate=0.010, error=-26.930
# >epoch=1140, lrate=0.010, error=-26.930
# >epoch=1141, lrate=0.010, error=-26.929
# >epoch=1142, lrate=0.010, error=-26.929
# >epoch=1143, lrate=0.010, error=-26.929
# >epoch=1144, lrate=0.010, error=-26.929
# >epoch=1145, lrate=0.010, error=-26.929
# >epoch=1146, lrate=0.010, error=-26.929
# >epoch=1147, lrate=0.010, error=-26.928
# >epoch=1148, lrate=0.010, error=-26.928
# >epoch=1149, lrate=0.010, error=-26.928
# >epoch=1150, lrate=0.010, error=-26.928
# >epoch=1151, lrate=0.010, error=-26.928
# >epoch=1152, lrate=0.010, error=-26.927
# >epoch=1153, lrate=0.010, error=-26.927
# >epoch=1154, lrate=0.010, error=-26.927
# >epoch=1155, lrate=0.010, error=-26.927
# >epoch=1156, lrate=0.010, error=-26.927
# >epoch=1157, lrate=0.010, error=-26.927
# >epoch=1158, lrate=0.010, error=-26.926
# >epoch=1159, lrate=0.010, error=-26.926
# >epoch=1160, lrate=0.010, error=-26.926
# >epoch=1161, lrate=0.010, error=-26.926
# >epoch=1162, lrate=0.010, error=-26.926
# >epoch=1163, lrate=0.010, error=-26.926
# >epoch=1164, lrate=0.010, error=-26.925
# >epoch=1165, lrate=0.010, error=-26.925
# >epoch=1166, lrate=0.010, error=-26.925
# >epoch=1167, lrate=0.010, error=-26.925
# >epoch=1168, lrate=0.010, error=-26.925
# >epoch=1169, lrate=0.010, error=-26.924
# >epoch=1170, lrate=0.010, error=-26.924
# >epoch=1171, lrate=0.010, error=-26.924
# >epoch=1172, lrate=0.010, error=-26.924
# >epoch=1173, lrate=0.010, error=-26.924
# >epoch=1174, lrate=0.010, error=-26.924
# >epoch=1175, lrate=0.010, error=-26.923
# >epoch=1176, lrate=0.010, error=-26.923
# >epoch=1177, lrate=0.010, error=-26.923
# >epoch=1178, lrate=0.010, error=-26.923
# >epoch=1179, lrate=0.010, error=-26.923
# >epoch=1180, lrate=0.010, error=-26.923
# >epoch=1181, lrate=0.010, error=-26.922
# >epoch=1182, lrate=0.010, error=-26.922
# >epoch=1183, lrate=0.010, error=-26.922
# >epoch=1184, lrate=0.010, error=-26.922
# >epoch=1185, lrate=0.010, error=-26.922
# >epoch=1186, lrate=0.010, error=-26.922
# >epoch=1187, lrate=0.010, error=-26.921
# >epoch=1188, lrate=0.010, error=-26.921
# >epoch=1189, lrate=0.010, error=-26.921
# >epoch=1190, lrate=0.010, error=-26.921
# >epoch=1191, lrate=0.010, error=-26.921
# >epoch=1192, lrate=0.010, error=-26.921
# >epoch=1193, lrate=0.010, error=-26.920
# >epoch=1194, lrate=0.010, error=-26.920
# >epoch=1195, lrate=0.010, error=-26.920
# >epoch=1196, lrate=0.010, error=-26.920
# >epoch=1197, lrate=0.010, error=-26.920
# >epoch=1198, lrate=0.010, error=-26.920
# >epoch=1199, lrate=0.010, error=-26.919
# >epoch=1200, lrate=0.010, error=-26.919
# >epoch=1201, lrate=0.010, error=-26.919
# >epoch=1202, lrate=0.010, error=-26.919
# >epoch=1203, lrate=0.010, error=-26.919
# >epoch=1204, lrate=0.010, error=-26.919
# >epoch=1205, lrate=0.010, error=-26.918
# >epoch=1206, lrate=0.010, error=-26.918
# >epoch=1207, lrate=0.010, error=-26.918
# >epoch=1208, lrate=0.010, error=-26.918
# >epoch=1209, lrate=0.010, error=-26.918
# >epoch=1210, lrate=0.010, error=-26.918
# >epoch=1211, lrate=0.010, error=-26.917
# >epoch=1212, lrate=0.010, error=-26.917
# >epoch=1213, lrate=0.010, error=-26.917
# >epoch=1214, lrate=0.010, error=-26.917
# >epoch=1215, lrate=0.010, error=-26.917
# >epoch=1216, lrate=0.010, error=-26.917
# >epoch=1217, lrate=0.010, error=-26.916
# >epoch=1218, lrate=0.010, error=-26.916
# >epoch=1219, lrate=0.010, error=-26.916
# >epoch=1220, lrate=0.010, error=-26.916
# >epoch=1221, lrate=0.010, error=-26.916
# >epoch=1222, lrate=0.010, error=-26.916
# >epoch=1223, lrate=0.010, error=-26.915
# >epoch=1224, lrate=0.010, error=-26.915
# >epoch=1225, lrate=0.010, error=-26.915
# >epoch=1226, lrate=0.010, error=-26.915
# ...
# >epoch=4616, lrate=0.010, error=-26.784
# >epoch=4617, lrate=0.010, error=-26.784
# >epoch=4618, lrate=0.010, error=-26.784
# >epoch=4619, lrate=0.010, error=-26.784
# >epoch=4620, lrate=0.010, error=-26.784
# >epoch=4621, lrate=0.010, error=-26.784
# >epoch=4622, lrate=0.010, error=-26.783
# >epoch=4623, lrate=0.010, error=-26.783
# >epoch=4624, lrate=0.010, error=-26.783
# >epoch=4625, lrate=0.010, error=-26.783
# >epoch=4626, lrate=0.010, error=-26.783
# >epoch=4627, lrate=0.010, error=-26.783
# >epoch=4628, lrate=0.010, error=-26.783
# >epoch=4629, lrate=0.010, error=-26.783
# >epoch=4630, lrate=0.010, error=-26.783
# >epoch=4631, lrate=0.010, error=-26.783
# >epoch=4632, lrate=0.010, error=-26.783
# >epoch=4633, lrate=0.010, error=-26.783
# >epoch=4634, lrate=0.010, error=-26.783
# >epoch=4635, lrate=0.010, error=-26.783
# >epoch=4636, lrate=0.010, error=-26.783
# >epoch=4637, lrate=0.010, error=-26.783
# >epoch=4638, lrate=0.010, error=-26.783
# >epoch=4639, lrate=0.010, error=-26.783
# >epoch=4640, lrate=0.010, error=-26.783
# >epoch=4641, lrate=0.010, error=-26.783
# >epoch=4642, lrate=0.010, error=-26.783
# >epoch=4643, lrate=0.010, error=-26.783
# >epoch=4644, lrate=0.010, error=-26.783
# >epoch=4645, lrate=0.010, error=-26.783
# >epoch=4646, lrate=0.010, error=-26.783
# >epoch=4647, lrate=0.010, error=-26.783
# >epoch=4648, lrate=0.010, error=-26.783
# >epoch=4649, lrate=0.010, error=-26.783
# >epoch=4650, lrate=0.010, error=-26.783
# >epoch=4651, lrate=0.010, error=-26.783
# >epoch=4652, lrate=0.010, error=-26.783
# >epoch=4653, lrate=0.010, error=-26.783
# >epoch=4654, lrate=0.010, error=-26.783
# >epoch=4655, lrate=0.010, error=-26.783
# >epoch=4656, lrate=0.010, error=-26.783
# >epoch=4657, lrate=0.010, error=-26.783
# >epoch=4658, lrate=0.010, error=-26.783
# >epoch=4659, lrate=0.010, error=-26.783
# >epoch=4660, lrate=0.010, error=-26.783
# >epoch=4661, lrate=0.010, error=-26.783
# >epoch=4662, lrate=0.010, error=-26.783
# >epoch=4663, lrate=0.010, error=-26.783
# >epoch=4664, lrate=0.010, error=-26.783
# >epoch=4665, lrate=0.010, error=-26.783
# >epoch=4666, lrate=0.010, error=-26.783
# >epoch=4667, lrate=0.010, error=-26.783
# >epoch=4668, lrate=0.010, error=-26.783
# >epoch=4669, lrate=0.010, error=-26.783
# >epoch=4670, lrate=0.010, error=-26.783
# >epoch=4671, lrate=0.010, error=-26.783
# >epoch=4672, lrate=0.010, error=-26.783
# >epoch=4673, lrate=0.010, error=-26.783
# >epoch=4674, lrate=0.010, error=-26.783
# >epoch=4675, lrate=0.010, error=-26.783
# >epoch=4676, lrate=0.010, error=-26.783
# >epoch=4677, lrate=0.010, error=-26.783
# >epoch=4678, lrate=0.010, error=-26.783
# >epoch=4679, lrate=0.010, error=-26.783
# >epoch=4680, lrate=0.010, error=-26.783
# >epoch=4681, lrate=0.010, error=-26.783
# >epoch=4682, lrate=0.010, error=-26.783
# >epoch=4683, lrate=0.010, error=-26.783
# >epoch=4684, lrate=0.010, error=-26.783
# >epoch=4685, lrate=0.010, error=-26.783
# >epoch=4686, lrate=0.010, error=-26.783
# >epoch=4687, lrate=0.010, error=-26.783
# >epoch=4688, lrate=0.010, error=-26.783
# >epoch=4689, lrate=0.010, error=-26.783
# >epoch=4690, lrate=0.010, error=-26.783
# >epoch=4691, lrate=0.010, error=-26.783
# >epoch=4692, lrate=0.010, error=-26.783
# >epoch=4693, lrate=0.010, error=-26.783
# >epoch=4694, lrate=0.010, error=-26.783
# >epoch=4695, lrate=0.010, error=-26.783
# >epoch=4696, lrate=0.010, error=-26.783
# >epoch=4697, lrate=0.010, error=-26.783
# >epoch=4698, lrate=0.010, error=-26.783
# >epoch=4699, lrate=0.010, error=-26.783
# >epoch=4700, lrate=0.010, error=-26.783
# >epoch=4701, lrate=0.010, error=-26.783
# >epoch=4702, lrate=0.010, error=-26.783
# >epoch=4703, lrate=0.010, error=-26.783
# >epoch=4704, lrate=0.010, error=-26.783
# >epoch=4705, lrate=0.010, error=-26.783
# >epoch=4706, lrate=0.010, error=-26.783
# >epoch=4707, lrate=0.010, error=-26.783
# >epoch=4708, lrate=0.010, error=-26.783
# >epoch=4709, lrate=0.010, error=-26.783
# >epoch=4710, lrate=0.010, error=-26.783
# >epoch=4711, lrate=0.010, error=-26.783
# >epoch=4712, lrate=0.010, error=-26.783
# >epoch=4713, lrate=0.010, error=-26.783
# >epoch=4714, lrate=0.010, error=-26.783
# >epoch=4715, lrate=0.010, error=-26.783
# >epoch=4716, lrate=0.010, error=-26.783
# >epoch=4717, lrate=0.010, error=-26.783
# >epoch=4718, lrate=0.010, error=-26.783
# >epoch=4719, lrate=0.010, error=-26.783
# >epoch=4720, lrate=0.010, error=-26.783
# >epoch=4721, lrate=0.010, error=-26.783
# >epoch=4722, lrate=0.010, error=-26.783
# >epoch=4723, lrate=0.010, error=-26.783
# >epoch=4724, lrate=0.010, error=-26.783
# >epoch=4725, lrate=0.010, error=-26.783
# >epoch=4726, lrate=0.010, error=-26.783
# >epoch=4727, lrate=0.010, error=-26.783
# >epoch=4728, lrate=0.010, error=-26.783
# >epoch=4729, lrate=0.010, error=-26.782
# >epoch=4730, lrate=0.010, error=-26.782
# >epoch=4731, lrate=0.010, error=-26.782
# >epoch=4732, lrate=0.010, error=-26.782
# >epoch=4733, lrate=0.010, error=-26.782
# >epoch=4734, lrate=0.010, error=-26.782
# >epoch=4735, lrate=0.010, error=-26.782
# >epoch=4736, lrate=0.010, error=-26.782
# >epoch=4737, lrate=0.010, error=-26.782
# >epoch=4738, lrate=0.010, error=-26.782
# >epoch=4739, lrate=0.010, error=-26.782
# >epoch=4740, lrate=0.010, error=-26.782
# >epoch=4741, lrate=0.010, error=-26.782
# >epoch=4742, lrate=0.010, error=-26.782
# >epoch=4743, lrate=0.010, error=-26.782
# >epoch=4744, lrate=0.010, error=-26.782
# >epoch=4745, lrate=0.010, error=-26.782
# >epoch=4746, lrate=0.010, error=-26.782
# >epoch=4747, lrate=0.010, error=-26.782
# >epoch=4748, lrate=0.010, error=-26.782
# >epoch=4749, lrate=0.010, error=-26.782
# >epoch=4750, lrate=0.010, error=-26.782
# >epoch=4751, lrate=0.010, error=-26.782
# >epoch=4752, lrate=0.010, error=-26.782
# >epoch=4753, lrate=0.010, error=-26.782
# >epoch=4754, lrate=0.010, error=-26.782
# >epoch=4755, lrate=0.010, error=-26.782
# >epoch=4756, lrate=0.010, error=-26.782
# >epoch=4757, lrate=0.010, error=-26.782
# >epoch=4758, lrate=0.010, error=-26.782
# >epoch=4759, lrate=0.010, error=-26.782
# >epoch=4760, lrate=0.010, error=-26.782
# >epoch=4761, lrate=0.010, error=-26.782
# >epoch=4762, lrate=0.010, error=-26.782
# >epoch=4763, lrate=0.010, error=-26.782
# >epoch=4764, lrate=0.010, error=-26.782
# >epoch=4765, lrate=0.010, error=-26.782
# >epoch=4766, lrate=0.010, error=-26.782
# >epoch=4767, lrate=0.010, error=-26.782
# >epoch=4768, lrate=0.010, error=-26.782
# >epoch=4769, lrate=0.010, error=-26.782
# >epoch=4770, lrate=0.010, error=-26.782
# >epoch=4771, lrate=0.010, error=-26.782
# >epoch=4772, lrate=0.010, error=-26.782
# >epoch=4773, lrate=0.010, error=-26.782
# >epoch=4774, lrate=0.010, error=-26.782
# >epoch=4775, lrate=0.010, error=-26.782
# >epoch=4776, lrate=0.010, error=-26.782
# >epoch=4777, lrate=0.010, error=-26.782
# >epoch=4778, lrate=0.010, error=-26.782
# >epoch=4779, lrate=0.010, error=-26.782
# >epoch=4780, lrate=0.010, error=-26.782
# >epoch=4781, lrate=0.010, error=-26.782
# >epoch=4782, lrate=0.010, error=-26.782
# >epoch=4783, lrate=0.010, error=-26.782
# >epoch=4784, lrate=0.010, error=-26.782
# >epoch=4785, lrate=0.010, error=-26.782
# >epoch=4786, lrate=0.010, error=-26.782
# >epoch=4787, lrate=0.010, error=-26.782
# >epoch=4788, lrate=0.010, error=-26.782
# >epoch=4789, lrate=0.010, error=-26.782
# >epoch=4790, lrate=0.010, error=-26.782
# >epoch=4791, lrate=0.010, error=-26.782
# >epoch=4792, lrate=0.010, error=-26.782
# >epoch=4793, lrate=0.010, error=-26.782
# >epoch=4794, lrate=0.010, error=-26.782
# >epoch=4795, lrate=0.010, error=-26.782
# >epoch=4796, lrate=0.010, error=-26.782
# >epoch=4797, lrate=0.010, error=-26.782
# >epoch=4798, lrate=0.010, error=-26.782
# >epoch=4799, lrate=0.010, error=-26.782
# >epoch=4800, lrate=0.010, error=-26.782
# >epoch=4801, lrate=0.010, error=-26.782
# >epoch=4802, lrate=0.010, error=-26.782
# >epoch=4803, lrate=0.010, error=-26.782
# >epoch=4804, lrate=0.010, error=-26.782
# >epoch=4805, lrate=0.010, error=-26.782
# >epoch=4806, lrate=0.010, error=-26.782
# >epoch=4807, lrate=0.010, error=-26.782
# >epoch=4808, lrate=0.010, error=-26.782
# >epoch=4809, lrate=0.010, error=-26.782
# >epoch=4810, lrate=0.010, error=-26.782
# >epoch=4811, lrate=0.010, error=-26.782
# >epoch=4812, lrate=0.010, error=-26.782
# >epoch=4813, lrate=0.010, error=-26.782
# >epoch=4814, lrate=0.010, error=-26.782
# >epoch=4815, lrate=0.010, error=-26.782
# >epoch=4816, lrate=0.010, error=-26.782
# >epoch=4817, lrate=0.010, error=-26.782
# >epoch=4818, lrate=0.010, error=-26.782
# >epoch=4819, lrate=0.010, error=-26.782
# >epoch=4820, lrate=0.010, error=-26.782
# >epoch=4821, lrate=0.010, error=-26.782
# >epoch=4822, lrate=0.010, error=-26.782
# >epoch=4823, lrate=0.010, error=-26.782
# >epoch=4824, lrate=0.010, error=-26.782
# >epoch=4825, lrate=0.010, error=-26.782
# >epoch=4826, lrate=0.010, error=-26.782
# >epoch=4827, lrate=0.010, error=-26.782
# >epoch=4828, lrate=0.010, error=-26.782
# >epoch=4829, lrate=0.010, error=-26.782
# >epoch=4830, lrate=0.010, error=-26.782
# >epoch=4831, lrate=0.010, error=-26.782
# >epoch=4832, lrate=0.010, error=-26.782
# >epoch=4833, lrate=0.010, error=-26.782
# >epoch=4834, lrate=0.010, error=-26.782
# >epoch=4835, lrate=0.010, error=-26.782
# >epoch=4836, lrate=0.010, error=-26.782
# >epoch=4837, lrate=0.010, error=-26.782
# >epoch=4838, lrate=0.010, error=-26.782
# >epoch=4839, lrate=0.010, error=-26.782
# >epoch=4840, lrate=0.010, error=-26.782
# >epoch=4841, lrate=0.010, error=-26.782
# >epoch=4842, lrate=0.010, error=-26.781
# >epoch=4843, lrate=0.010, error=-26.781
# >epoch=4844, lrate=0.010, error=-26.781
# >epoch=4845, lrate=0.010, error=-26.781
# >epoch=4846, lrate=0.010, error=-26.781
# >epoch=4847, lrate=0.010, error=-26.781
# >epoch=4848, lrate=0.010, error=-26.781
# >epoch=4849, lrate=0.010, error=-26.781
# >epoch=4850, lrate=0.010, error=-26.781
# >epoch=4851, lrate=0.010, error=-26.781
# >epoch=4852, lrate=0.010, error=-26.781
# >epoch=4853, lrate=0.010, error=-26.781
# >epoch=4854, lrate=0.010, error=-26.781
# >epoch=4855, lrate=0.010, error=-26.781
# >epoch=4856, lrate=0.010, error=-26.781
# >epoch=4857, lrate=0.010, error=-26.781
# >epoch=4858, lrate=0.010, error=-26.781
# >epoch=4859, lrate=0.010, error=-26.781
# >epoch=4860, lrate=0.010, error=-26.781
# >epoch=4861, lrate=0.010, error=-26.781
# >epoch=4862, lrate=0.010, error=-26.781
# >epoch=4863, lrate=0.010, error=-26.781
# >epoch=4864, lrate=0.010, error=-26.781
# >epoch=4865, lrate=0.010, error=-26.781
# >epoch=4866, lrate=0.010, error=-26.781
# >epoch=4867, lrate=0.010, error=-26.781
# >epoch=4868, lrate=0.010, error=-26.781
# >epoch=4869, lrate=0.010, error=-26.781
# >epoch=4870, lrate=0.010, error=-26.781
# >epoch=4871, lrate=0.010, error=-26.781
# >epoch=4872, lrate=0.010, error=-26.781
# >epoch=4873, lrate=0.010, error=-26.781
# >epoch=4874, lrate=0.010, error=-26.781
# >epoch=4875, lrate=0.010, error=-26.781
# >epoch=4876, lrate=0.010, error=-26.781
# >epoch=4877, lrate=0.010, error=-26.781
# >epoch=4878, lrate=0.010, error=-26.781
# >epoch=4879, lrate=0.010, error=-26.781
# >epoch=4880, lrate=0.010, error=-26.781
# >epoch=4881, lrate=0.010, error=-26.781
# >epoch=4882, lrate=0.010, error=-26.781
# >epoch=4883, lrate=0.010, error=-26.781
# >epoch=4884, lrate=0.010, error=-26.781
# >epoch=4885, lrate=0.010, error=-26.781
# >epoch=4886, lrate=0.010, error=-26.781
# >epoch=4887, lrate=0.010, error=-26.781
# >epoch=4888, lrate=0.010, error=-26.781
# >epoch=4889, lrate=0.010, error=-26.781
# >epoch=4890, lrate=0.010, error=-26.781
# >epoch=4891, lrate=0.010, error=-26.781
# >epoch=4892, lrate=0.010, error=-26.781
# >epoch=4893, lrate=0.010, error=-26.781
# >epoch=4894, lrate=0.010, error=-26.781
# >epoch=4895, lrate=0.010, error=-26.781
# >epoch=4896, lrate=0.010, error=-26.781
# >epoch=4897, lrate=0.010, error=-26.781
# >epoch=4898, lrate=0.010, error=-26.781
# >epoch=4899, lrate=0.010, error=-26.781
# >epoch=4900, lrate=0.010, error=-26.781
# >epoch=4901, lrate=0.010, error=-26.781
# >epoch=4902, lrate=0.010, error=-26.781
# >epoch=4903, lrate=0.010, error=-26.781
# >epoch=4904, lrate=0.010, error=-26.781
# >epoch=4905, lrate=0.010, error=-26.781
# >epoch=4906, lrate=0.010, error=-26.781
# >epoch=4907, lrate=0.010, error=-26.781
# >epoch=4908, lrate=0.010, error=-26.781
# >epoch=4909, lrate=0.010, error=-26.781
# >epoch=4910, lrate=0.010, error=-26.781
# >epoch=4911, lrate=0.010, error=-26.781
# >epoch=4912, lrate=0.010, error=-26.781
# >epoch=4913, lrate=0.010, error=-26.781
# >epoch=4914, lrate=0.010, error=-26.781
# >epoch=4915, lrate=0.010, error=-26.781
# >epoch=4916, lrate=0.010, error=-26.781
# >epoch=4917, lrate=0.010, error=-26.781
# >epoch=4918, lrate=0.010, error=-26.781
# >epoch=4919, lrate=0.010, error=-26.781
# >epoch=4920, lrate=0.010, error=-26.781
# >epoch=4921, lrate=0.010, error=-26.781
# >epoch=4922, lrate=0.010, error=-26.781
# >epoch=4923, lrate=0.010, error=-26.781
# >epoch=4924, lrate=0.010, error=-26.781
# >epoch=4925, lrate=0.010, error=-26.781
# >epoch=4926, lrate=0.010, error=-26.781
# >epoch=4927, lrate=0.010, error=-26.781
# >epoch=4928, lrate=0.010, error=-26.781
# >epoch=4929, lrate=0.010, error=-26.781
# >epoch=4930, lrate=0.010, error=-26.781
# >epoch=4931, lrate=0.010, error=-26.781
# >epoch=4932, lrate=0.010, error=-26.781
# >epoch=4933, lrate=0.010, error=-26.781
# >epoch=4934, lrate=0.010, error=-26.781
# >epoch=4935, lrate=0.010, error=-26.781
# >epoch=4936, lrate=0.010, error=-26.781
# >epoch=4937, lrate=0.010, error=-26.781
# >epoch=4938, lrate=0.010, error=-26.781
# >epoch=4939, lrate=0.010, error=-26.781
# >epoch=4940, lrate=0.010, error=-26.781
# >epoch=4941, lrate=0.010, error=-26.781
# >epoch=4942, lrate=0.010, error=-26.781
# >epoch=4943, lrate=0.010, error=-26.781
# >epoch=4944, lrate=0.010, error=-26.781
# >epoch=4945, lrate=0.010, error=-26.781
# >epoch=4946, lrate=0.010, error=-26.781
# >epoch=4947, lrate=0.010, error=-26.781
# >epoch=4948, lrate=0.010, error=-26.781
# >epoch=4949, lrate=0.010, error=-26.781
# >epoch=4950, lrate=0.010, error=-26.781
# >epoch=4951, lrate=0.010, error=-26.781
# >epoch=4952, lrate=0.010, error=-26.781
# >epoch=4953, lrate=0.010, error=-26.781
# >epoch=4954, lrate=0.010, error=-26.781
# >epoch=4955, lrate=0.010, error=-26.781
# >epoch=4956, lrate=0.010, error=-26.781
# >epoch=4957, lrate=0.010, error=-26.781
# >epoch=4958, lrate=0.010, error=-26.781
# >epoch=4959, lrate=0.010, error=-26.781
# >epoch=4960, lrate=0.010, error=-26.780
# >epoch=4961, lrate=0.010, error=-26.780
# >epoch=4962, lrate=0.010, error=-26.780
# >epoch=4963, lrate=0.010, error=-26.780
# >epoch=4964, lrate=0.010, error=-26.780
# >epoch=4965, lrate=0.010, error=-26.780
# >epoch=4966, lrate=0.010, error=-26.780
# >epoch=4967, lrate=0.010, error=-26.780
# >epoch=4968, lrate=0.010, error=-26.780
# >epoch=4969, lrate=0.010, error=-26.780
# >epoch=4970, lrate=0.010, error=-26.780
# >epoch=4971, lrate=0.010, error=-26.780
# >epoch=4972, lrate=0.010, error=-26.780
# >epoch=4973, lrate=0.010, error=-26.780
# >epoch=4974, lrate=0.010, error=-26.780
# >epoch=4975, lrate=0.010, error=-26.780
# >epoch=4976, lrate=0.010, error=-26.780
# >epoch=4977, lrate=0.010, error=-26.780
# >epoch=4978, lrate=0.010, error=-26.780
# >epoch=4979, lrate=0.010, error=-26.780
# >epoch=4980, lrate=0.010, error=-26.780
# >epoch=4981, lrate=0.010, error=-26.780
# >epoch=4982, lrate=0.010, error=-26.780
# >epoch=4983, lrate=0.010, error=-26.780
# >epoch=4984, lrate=0.010, error=-26.780
# >epoch=4985, lrate=0.010, error=-26.780
# >epoch=4986, lrate=0.010, error=-26.780
# >epoch=4987, lrate=0.010, error=-26.780
# >epoch=4988, lrate=0.010, error=-26.780
# >epoch=4989, lrate=0.010, error=-26.780
# >epoch=4990, lrate=0.010, error=-26.780
# >epoch=4991, lrate=0.010, error=-26.780
# >epoch=4992, lrate=0.010, error=-26.780
# >epoch=4993, lrate=0.010, error=-26.780
# >epoch=4994, lrate=0.010, error=-26.780
# >epoch=4995, lrate=0.010, error=-26.780
# >epoch=4996, lrate=0.010, error=-26.780
# >epoch=4997, lrate=0.010, error=-26.780
# >epoch=4998, lrate=0.010, error=-26.780
# >epoch=4999, lrate=0.010, error=-26.780
# [{'weights': [0.14269861212818333, 0.8490494893530813, 0.7641973934279866], 'output': 1.0, 'delta': -0.0}, {'weights': [0.28429502314780203, 0.5172256103339355, 0.451557528886679], 'output': 1.0, 'delta': -0.0}, {'weights': [0.6515999751674676, 0.7887286565522266, 0.09386011521674797], 'output': 1.0, 'delta': -0.0}, {'weights': [-2.8459820288415245, 2.375514090397704, -1.1245031942512422], 'output': 1.0, 'delta': 0.0}]
# [{'weights': [-1.306117824465025, -2.0670118970079696, -1.6257166643661571, 8.341962100677772, -1.8423425412675547], 'output': 0.8163166539452361, 'delta': 0.18368334605476389}]

# %%
e = 0
for x in dataset:
    y = forward_propagate(network, x[:2])
    e+= (x[-1]- 1*((y[-1])>0.5))**2

print("errores:",e)
# Out:
# errores: 11.0
