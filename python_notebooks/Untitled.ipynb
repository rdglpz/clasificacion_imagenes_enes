# %%
import numpy as np
import math as math
import matplotlib.pyplot as plt

# %%
n = np.arange(1,10000)

# %%
# altura del arbol binario requerido para que cada bin tenga 1 indice aproximadamente
n = 1e5
altura = np.floor(np.log2(n))
altura


n/2
# Out:
# 50000.0

# %%
mmax = 15
tmax = 15


lmax = mmax*tmax-tmax

print(lmax)

combinations = (2**lmax)
combinations/2
# Out:
# 210
# 8.22752278660603e+62

# %%
c = list([])
c2 = list([])
c3 = list([])



for i in range(1,int(n)):
    c.append(i)
    c2.append(i*np.log2(i))
    c3.append(n)

# %%
plt.plot(c)
plt.plot(c2)

plt.show()

# %%
plt.plot(np.cumsum(np.array(c)))
plt.plot(np.cumsum(np.array(c2)))
plt.plot(np.cumsum(np.array(c3)))

# %%
c
# Out:
# [0.0,
#  0.5849625007211562,
#  1.0,
#  1.3219280948873624,
#  1.584962500721156,
#  1.8073549220576042,
#  2.0,
#  2.169925001442312,
#  2.321928094887362,
#  2.4594316186372973,
#  2.584962500721156,
#  2.700439718141092,
#  2.807354922057604,
#  2.9068905956085187,
#  3.0,
#  3.0874628412503395,
#  3.169925001442312,
#  3.2479275134435857,
#  3.321928094887362,
#  3.3923174227787602,
#  3.4594316186372973,
#  3.523561956057013,
#  3.584962500721156,
#  3.643856189774725,
#  3.700439718141092,
#  3.7548875021634687,
#  3.807354922057604,
#  3.8579809951275723,
#  3.9068905956085187,
#  3.9541963103868754,
#  4.0,
#  4.044394119358453,
#  4.087462841250339,
#  4.129283016944966,
#  4.169925001442312,
#  4.20945336562895,
#  4.247927513443585,
#  4.285402218862249,
#  4.321928094887363,
#  4.357552004618084,
#  4.392317422778761,
#  4.426264754702098,
#  4.459431618637297,
#  4.491853096329675,
#  4.523561956057013,
#  4.554588851677638,
#  4.584962500721156,
#  4.614709844115208,
# ...
